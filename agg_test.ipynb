# %%
# import requirements 
import requests
import re
import pandas as pd
import geopandas as gpd
from arcgis.gis import GIS
import os
import numpy as np
from arcgis.features import FeatureLayerCollection
from arcgis.features import FeatureSet, GeoAccessor
from arcgis.geometry import Geometry

# %%
#Import external files
governorate_municipality = gpd.read_file("UNEP_Gaza_Governorate_Municipality_Singleparts_POINTS.gpkg")
governorate_municipality = governorate_municipality.to_crs(epsg=4326)
governorate_municipality.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Authentication credentials
KOBO_USERNAME = "guilherme_iablonovski"
KOBO_PASSWORD = "k0b0Senha"
export_token = "f72722c6ffe97db14144325853528a4b7a1c059b"

# %%
#Recycled Aggregate Request API endpoint
kobo_api_url = "https://kf.kobotoolbox.org/api/v2/assets/akPnoN3KN4wL7TyuPzHGLu/export-settings/estEZQ8pe5N4cdfZ4zvnd6s"

# %%
def getKoboForm(url):
    # Create a session with authentication
    session = requests.Session()
    session.auth = (KOBO_USERNAME, KOBO_PASSWORD)

    # Construct the export URL
    kobo_export_url = f"{url}/data.xlsx"#?format=csv&token={export_token}"

    # Fetch data using the authenticated session
    response = session.get(kobo_export_url)

    # Check if the request was successful
    if response.status_code == 200:
        # Load data into a pandas DataFrame
        kobo_data = pd.read_excel(response.content)
        kobo_data.head()
        return kobo_data
    else:
        print("Error:", response.status_code)
        
kobo_data = getKoboForm(kobo_api_url)
# Out:
# C:\Users\joses\AppData\Local\Temp\ipykernel_8824\399000899.py:15: FutureWarning: Passing bytes to 'read_excel' is deprecated and will be removed in a future version. To read from a byte string, wrap it in a `BytesIO` object.
#   kobo_data = pd.read_excel(response.content)

# %%
kobo_data
# Out:
#         \
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN
# 10 NaN
# 11 NaN
#
#     Please fill in this form if you represent a non-government organisation requesting recycled aggregate.  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
#    Requesting agency                     Please specify  Contact person name  \
# 0              Other                        MSF-Holland  MAHMOUD A. ABUJOUDA
# 1              Other                             UNICEF   Mohammed M K Qasem
# 2              Other                               ICRC           Ahmed Diab
# 3               UNDP                                NaN    Mohammed Alghouti
# 4              Other             Al Braeij Municipality    Mohammed Alghouti
# 5              Other           Al Nuseirat Municipality    Mohammed Alghouti
# 6               UNDP                                NaN    Mohammed Alghouti
# 7              Other              World Central kitchen   Bader El Khazendar
# 8              Other  Palestinian Housing Council (PHC)         Haitham Aqel
# 9              Other  Palestinian Housing Council (PHC)         Haitham Aqel
# 10             Other   Palestinian Housing Council (PHC         Haitham Aqel
# 11               IOM                                NaN                 Test
#
#    Contact person phone number             Contact person email address  \
# 0                +970591600938          gaza-watsan-spvisr3@oca.msf.org
# 1                   0562562314                        mqasem@unicef.org
# 2                   0567289180                         ahmdiab@icrc.org
# 3                   0599038880               mohammed.alghouti@undp.org
# 4                   0599038880               mohammed.alghouti@undp.org
# 5                   0599038880               mohammed.alghouti@undp.org
# 6                   0599038880               mohammed.alghouti@undp.org
# 7                   0567802036  balkhozendar.rc@worldcentralkitchen.org
# 8                   0599188418                        haqel@phc-pal.org
# 9                   0599188418                        haqel@phc-pal.org
# 10                  0599188418                        haqel@phc-pal.org
# 11                        Test                                     Test
#
#    Location of planned intervention(s)  \
# 0                        Deir Al-Balah
# 1                        Deir Al-Balah
# 2                  Deir Al-Balah Rafah
# 3                        Deir Al-Balah
# 4                        Deir Al-Balah
# 5                        Deir Al-Balah
# 6                        Deir Al-Balah
# 7                          Khan Younis
# 8                                 Gaza
# 9                          Khan Younis
# 10                         Khan Younis
# 11                         Khan Younis
#
#    Please specify the municipality (Deir Al-Balah)  \
# 0                                       Az Zawayda
# 1                                    Deir al Balah
# 2                         Az Zawayda Deir al Balah
# 3                                    Deir al Balah
# 4                                        Al Bureij
# 5                                      An Nuseirat
# 6                                       Az Zawayda
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
#
#    Please specify the municipality (Gaza)  ...        _id  \
# 0                                     NaN  ...  604077890
# 1                                     NaN  ...  604813438
# 2                                     NaN  ...  606512399
# 3                                     NaN  ...  606858488
# 4                                     NaN  ...  609454328
# 5                                     NaN  ...  609455837
# 6                                     NaN  ...  609637295
# 7                                     NaN  ...  612759008
# 8                                    Gaza  ...  613474735
# 9                                     NaN  ...  613474744
# 10                                    NaN  ...  613480635
# 11                                    NaN  ...  614022853
#
#                                    _uuid    _submission_time  \
# 0   e33f49a9-63e9-4262-8f99-99ba07f4daf8 2025-11-12 12:32:05
# 1   bc76a934-ea74-4f65-b6ac-857128456532 2025-11-13 10:24:31
# 2   cd9723e6-a304-4c8e-990d-15f12681a02b 2025-11-15 12:58:40
# 3   fd54b542-871d-45ba-b5e9-044850dc14cd 2025-11-16 06:57:48
# 4   c546fc60-ef9a-45f4-a8fa-2f6a22c08a55 2025-11-19 09:40:00
# 5   8285dcf5-8401-4734-b42a-8c39efedd3b0 2025-11-19 09:41:32
# 6   5c8779c3-12b7-41cb-a642-80736fde545b 2025-11-19 12:46:51
# 7   da5a6db7-b859-43ce-9e54-5cd46d808842 2025-11-23 09:11:36
# 8   2e8ac8cf-9e90-4634-94c5-e6729ce2cfc3 2025-11-24 09:37:18
# 9   10a3bd75-3818-4f1d-b19c-65b0ce6368a2 2025-11-24 09:37:19
# 10  621b9a9a-67d1-4af0-b094-e0dd6c5629b6 2025-11-24 09:43:30
# 11  d58ac243-1098-4dd8-93c5-eccb2a9e66a8 2025-11-24 19:53:01
#
#    _validation_status  _notes            _status _submitted_by  \
# 0                 NaN     NaN  submitted_via_web           NaN
# 1                 NaN     NaN  submitted_via_web           NaN
# 2                 NaN     NaN  submitted_via_web           NaN
# 3                 NaN     NaN  submitted_via_web           NaN
# 4                 NaN     NaN  submitted_via_web           NaN
# 5                 NaN     NaN  submitted_via_web           NaN
# 6                 NaN     NaN  submitted_via_web           NaN
# 7                 NaN     NaN  submitted_via_web           NaN
# 8                 NaN     NaN  submitted_via_web           NaN
# 9                 NaN     NaN  submitted_via_web           NaN
# 10                NaN     NaN  submitted_via_web           NaN
# 11                NaN     NaN  submitted_via_web           NaN
#
#                __version__ _tags _index
# 0   vCzxNRM55nRLyNcVVYvNow   NaN      1
# 1   vCzxNRM55nRLyNcVVYvNow   NaN      2
# 2   vCzxNRM55nRLyNcVVYvNow   NaN      3
# 3   vCzxNRM55nRLyNcVVYvNow   NaN      4
# 4   vCzxNRM55nRLyNcVVYvNow   NaN      5
# 5   vCzxNRM55nRLyNcVVYvNow   NaN      6
# 6   vCzxNRM55nRLyNcVVYvNow   NaN      7
# 7   vCzxNRM55nRLyNcVVYvNow   NaN      8
# 8   vCzxNRM55nRLyNcVVYvNow   NaN      9
# 9   vCzxNRM55nRLyNcVVYvNow   NaN     10
# 10  vCzxNRM55nRLyNcVVYvNow   NaN     11
# 11  vCzxNRM55nRLyNcVVYvNow   NaN     12
#
# [12 rows x 31 columns]

# %%
# Identifica as colunas que começam com "Please specify the municipality"
cols = [c for c in kobo_data.columns if c.startswith("Please specify the municipality")]

# %%
# Cria uma lista para armazenar os registros explodidos
records = []

# Itera sobre cada linha e coluna dessas
for _, row in kobo_data.iterrows():
    base_data = {col: row[col] for col in kobo_data.columns if col not in cols}  # mantém outras colunas

    for col in cols:
        val = row[col]
        if pd.isna(val):
            continue

        # Extrai o nome entre parênteses
        match = re.search(r'\((.*?)\)', col)
        governo = match.group(1).strip() if match else ''

        # Divide as respostas usando ". " como separador
        municipios = re.split(r'(?<=\.)\s+', str(val).strip())

        # Limpa e forma a nova lista com "Governo_Município"
        for m in municipios:
            m = m.strip().rstrip('.')
            if m:
                new_row = base_data.copy()
                new_row['Gov_Mun'] = f"{governo}_{m}"
                records.append(new_row)

# Cria o novo DataFrame com as linhas expandidas
kobo_data_exploded = pd.DataFrame(records).reset_index(drop=True)

# %%
kobo_data_exploded
# Out:
#         \
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN
# 10 NaN
# 11 NaN
# 12 NaN
#
#     Please fill in this form if you represent a non-government organisation requesting recycled aggregate.  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#    Requesting agency                     Please specify  Contact person name  \
# 0              Other                        MSF-Holland  MAHMOUD A. ABUJOUDA
# 1              Other                             UNICEF   Mohammed M K Qasem
# 2              Other                               ICRC           Ahmed Diab
# 3              Other                               ICRC           Ahmed Diab
# 4               UNDP                                NaN    Mohammed Alghouti
# 5              Other             Al Braeij Municipality    Mohammed Alghouti
# 6              Other           Al Nuseirat Municipality    Mohammed Alghouti
# 7               UNDP                                NaN    Mohammed Alghouti
# 8              Other              World Central kitchen   Bader El Khazendar
# 9              Other  Palestinian Housing Council (PHC)         Haitham Aqel
# 10             Other  Palestinian Housing Council (PHC)         Haitham Aqel
# 11             Other   Palestinian Housing Council (PHC         Haitham Aqel
# 12               IOM                                NaN                 Test
#
#    Contact person phone number             Contact person email address  \
# 0                +970591600938          gaza-watsan-spvisr3@oca.msf.org
# 1                   0562562314                        mqasem@unicef.org
# 2                   0567289180                         ahmdiab@icrc.org
# 3                   0567289180                         ahmdiab@icrc.org
# 4                   0599038880               mohammed.alghouti@undp.org
# 5                   0599038880               mohammed.alghouti@undp.org
# 6                   0599038880               mohammed.alghouti@undp.org
# 7                   0599038880               mohammed.alghouti@undp.org
# 8                   0567802036  balkhozendar.rc@worldcentralkitchen.org
# 9                   0599188418                        haqel@phc-pal.org
# 10                  0599188418                        haqel@phc-pal.org
# 11                  0599188418                        haqel@phc-pal.org
# 12                        Test                                     Test
#
#    Location of planned intervention(s)  \
# 0                        Deir Al-Balah
# 1                        Deir Al-Balah
# 2                  Deir Al-Balah Rafah
# 3                  Deir Al-Balah Rafah
# 4                        Deir Al-Balah
# 5                        Deir Al-Balah
# 6                        Deir Al-Balah
# 7                        Deir Al-Balah
# 8                          Khan Younis
# 9                                 Gaza
# 10                         Khan Younis
# 11                         Khan Younis
# 12                         Khan Younis
#
#                    Intended use of recycled materials  Please specify.1  ...  \
# 0   Ground preparation (filling / backfilling / le...               NaN  ...
# 1                                         Landscaping               NaN  ...
# 2   Road rehabilitation Ground preparation (fillin...               NaN  ...
# 3   Road rehabilitation Ground preparation (fillin...               NaN  ...
# 4   Ground preparation (filling / backfilling / le...               NaN  ...
# 5                                 Road rehabilitation               NaN  ...
# 6   Road rehabilitation Ground preparation (fillin...               NaN  ...
# 7                                 Road rehabilitation               NaN  ...
# 8   Road rehabilitation Ground preparation (fillin...               NaN  ...
# 9   Ground preparation (filling / backfilling / le...               NaN  ...
# 10  Ground preparation (filling / backfilling / le...               NaN  ...
# 11  Ground preparation (filling / backfilling / le...               NaN  ...
# 12                                Road rehabilitation               NaN  ...
#
#                                    _uuid    _submission_time  \
# 0   e33f49a9-63e9-4262-8f99-99ba07f4daf8 2025-11-12 12:32:05
# 1   bc76a934-ea74-4f65-b6ac-857128456532 2025-11-13 10:24:31
# 2   cd9723e6-a304-4c8e-990d-15f12681a02b 2025-11-15 12:58:40
# 3   cd9723e6-a304-4c8e-990d-15f12681a02b 2025-11-15 12:58:40
# 4   fd54b542-871d-45ba-b5e9-044850dc14cd 2025-11-16 06:57:48
# 5   c546fc60-ef9a-45f4-a8fa-2f6a22c08a55 2025-11-19 09:40:00
# 6   8285dcf5-8401-4734-b42a-8c39efedd3b0 2025-11-19 09:41:32
# 7   5c8779c3-12b7-41cb-a642-80736fde545b 2025-11-19 12:46:51
# 8   da5a6db7-b859-43ce-9e54-5cd46d808842 2025-11-23 09:11:36
# 9   2e8ac8cf-9e90-4634-94c5-e6729ce2cfc3 2025-11-24 09:37:18
# 10  10a3bd75-3818-4f1d-b19c-65b0ce6368a2 2025-11-24 09:37:19
# 11  621b9a9a-67d1-4af0-b094-e0dd6c5629b6 2025-11-24 09:43:30
# 12  d58ac243-1098-4dd8-93c5-eccb2a9e66a8 2025-11-24 19:53:01
#
#    _validation_status _notes            _status  _submitted_by  \
# 0                 NaN    NaN  submitted_via_web            NaN
# 1                 NaN    NaN  submitted_via_web            NaN
# 2                 NaN    NaN  submitted_via_web            NaN
# 3                 NaN    NaN  submitted_via_web            NaN
# 4                 NaN    NaN  submitted_via_web            NaN
# 5                 NaN    NaN  submitted_via_web            NaN
# 6                 NaN    NaN  submitted_via_web            NaN
# 7                 NaN    NaN  submitted_via_web            NaN
# 8                 NaN    NaN  submitted_via_web            NaN
# 9                 NaN    NaN  submitted_via_web            NaN
# 10                NaN    NaN  submitted_via_web            NaN
# 11                NaN    NaN  submitted_via_web            NaN
# 12                NaN    NaN  submitted_via_web            NaN
#
#                __version__ _tags _index  \
# 0   vCzxNRM55nRLyNcVVYvNow   NaN      1
# 1   vCzxNRM55nRLyNcVVYvNow   NaN      2
# 2   vCzxNRM55nRLyNcVVYvNow   NaN      3
# 3   vCzxNRM55nRLyNcVVYvNow   NaN      3
# 4   vCzxNRM55nRLyNcVVYvNow   NaN      4
# 5   vCzxNRM55nRLyNcVVYvNow   NaN      5
# 6   vCzxNRM55nRLyNcVVYvNow   NaN      6
# 7   vCzxNRM55nRLyNcVVYvNow   NaN      7
# 8   vCzxNRM55nRLyNcVVYvNow   NaN      8
# 9   vCzxNRM55nRLyNcVVYvNow   NaN      9
# 10  vCzxNRM55nRLyNcVVYvNow   NaN     10
# 11  vCzxNRM55nRLyNcVVYvNow   NaN     11
# 12  vCzxNRM55nRLyNcVVYvNow   NaN     12
#
#                                    Gov_Mun
# 0                 Deir Al-Balah_Az Zawayda
# 1              Deir Al-Balah_Deir al Balah
# 2   Deir Al-Balah_Az Zawayda Deir al Balah
# 3                              Rafah_Rafah
# 4              Deir Al-Balah_Deir al Balah
# 5                  Deir Al-Balah_Al Bureij
# 6                Deir Al-Balah_An Nuseirat
# 7                 Deir Al-Balah_Az Zawayda
# 8                    Khan Younis_Al Qarara
# 9                                Gaza_Gaza
# 10                  Khan Younis_Khan Yunis
# 11                  Khan Younis_Khan Yunis
# 12           Khan Younis_'Abasan al Kabira
#
# [13 rows x 27 columns]

# %%
#### INITIAL CLEANING

#Standardize data for municipalities without neighborhoods

def standardize(df):

    kobo_data_0 = df.replace(0, None)  
    return kobo_data_0

kobo_data_exploded = standardize(kobo_data_exploded)

# Faz o join com o gdf, mantendo todos os municípios originais

gdf_filtrado = governorate_municipality.merge(kobo_data_exploded, on='Gov_Mun', how='right')

# %%
gdf_filtrado.columns
# Out:
# Index(['OBJECTID', 'Neighborhood', 'Municipality', 'Governorate',
#        'Shape__Area', 'Shape__Length', 'ArabicName', 'governate_name',
#        'municipality_name', 'neighborhood_name', 'Location_gdf', 'Gov_Mun',
#        'geometry', ' ',
#        'Please fill in this form if you represent a non-government organisation requesting recycled aggregate.',
#        'Requesting agency', 'Please specify', 'Contact person name',
#        'Contact person phone number', 'Contact person email address',
#        'Location of planned intervention(s)',
#        'Intended use of recycled materials', 'Please specify.1',
#        'Requested Quantity', 'Specify the measurement unit',
#        'Additional Comments',
#        'I acknowledge that it is my responsibility to collect the recycled aggregate from the debris recycling center. Furthermore, I accept full responsibility and liability for the use of the recycled aggregate according to Palestinian standard specifications and applicable environmental guidelines.',
#        'I agree to report to the DWG on the use of the recycled aggregate including providing photographic documentation.',
#        'Click on the Validate button below to send your response. Plase visit the Gaza DWG Website to find the responses to this form on the dashboards available.',
#        '_id', '_uuid', '_submission_time', '_validation_status', '_notes',
#        '_status', '_submitted_by', '__version__', '_tags', '_index'],
#       dtype='object')

# %%
# Create string column to 'submission_time'
gdf_filtrado['hora_subm'] = gdf_filtrado['_submission_time'].astype(str)

# %%
#Handle columns so they are not modified by arcgis when uploaded
def makeArcGISfriendly(df):
    df.columns = df.columns.str.replace(r"[ ]", "_", regex=True)
    df.columns = df.columns.str.replace(r"[.]", "_", regex=True)
    df.columns = df.columns.str.replace(r"[?]", "_", regex=True)
    df.columns = df.columns.str.replace(r"[']", "", regex=True)
    df.columns = df.columns.str.replace(r"[(]", "", regex=True)
    df.columns = df.columns.str.replace(r"[)]", "", regex=True)
    df.columns = df.columns.str.replace(r"[[]", "", regex=True)
    df.columns = df.columns.str.replace(r"[]]", "", regex=True)
    df.columns = df.columns.str.replace(r"[%]", "_", regex=True)
    df.columns = map(str.lower, df.columns)
    
    # Remove leading underscores
    df = df.rename(columns={
        '_id':'f_id',
        '_uuid':'f_uuid',
    })
    df.columns = df.columns.str.lstrip('_')
    
    #Truncate and ensure uniqueness
    seen = {}
    final_cols = []
    max_length = 31
    for col in df.columns:
        base = col[:max_length]
        new_col = base
        i = 1
        while new_col in seen:
            suffix = f"_{i}"
            trim_len = max_length - len(suffix)
            new_col = base[:trim_len] + suffix
            i += 1
        seen[new_col] = True
        final_cols.append(new_col)
    
    # Step 4: Apply to DataFrame
    df.columns = final_cols
    return df

gdf_exploded = makeArcGISfriendly(gdf_filtrado)
# Out:
# c:\Users\joses\anaconda3\Lib\site-packages\pandas\core\strings\object_array.py:172: FutureWarning: Possible nested set at position 1
#   pat = re.compile(pat, flags=flags)

# %%
def simplifyGeometries(df):
    df['geometry'] = df['geometry'].centroid
    return df
    
gdf_exploded = simplifyGeometries(gdf_exploded)

seen = set()
unique_flags = []

for _, row in gdf_exploded.iterrows():
    if row['f_id'] in seen:
        unique_flags.append('')
    else:
        unique_flags.append('yes')
        seen.add(row['f_id'])

gdf_exploded['unique_'] = unique_flags
# Out:
# C:\Users\joses\AppData\Local\Temp\ipykernel_8824\3564463087.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   df['geometry'] = df['geometry'].centroid

# %%
gdf_exploded.columns
# Out:
# Index(['objectid', 'neighborhood', 'municipality', 'governorate',
#        'shape__area', 'shape__length', 'arabicname', 'governate_name',
#        'municipality_name', 'neighborhood_name', 'location_gdf', 'gov_mun',
#        'geometry', '', 'please_fill_in_this_form_if_you', 'requesting_agency',
#        'please_specify', 'contact_person_name', 'contact_person_phone_number',
#        'contact_person_email_address', 'location_of_planned_interventio',
#        'intended_use_of_recycled_materi', 'please_specify_1',
#        'requested_quantity', 'specify_the_measurement_unit',
#        'additional_comments', 'i_acknowledge_that_it_is_my_res',
#        'i_agree_to_report_to_the_dwg_on', 'click_on_the_validate_button_be',
#        'f_id', 'f_uuid', 'submission_time', 'validation_status', 'notes',
#        'status', 'submitted_by', 'version__', 'tags', 'index', 'hora_subm',
#        'unique_'],
#       dtype='object')

# %%
# Clean columns
gdf_colunas = gdf_exploded[['objectid', 'neighborhood', 'municipality', 'governorate', 'arabicname', 'governate_name',
       'municipality_name', 'neighborhood_name', 'location_gdf', 'gov_mun',
       'geometry', 'requesting_agency', 'please_specify', 'contact_person_name', 'contact_person_phone_number',
       'contact_person_email_address', 'location_of_planned_interventio',
       'intended_use_of_recycled_materi', 'please_specify_1',
       'requested_quantity', 'specify_the_measurement_unit', 'hora_subm',
       'f_id', 'f_uuid', 'submission_time', 'status', 'submitted_by', 'version__', 'tags', 'index',]]



# Repair columns names
gdf_colunas.columns = (
    gdf_colunas.columns
      .str.normalize('NFKD')
      .str.encode('ascii', errors='ignore').str.decode('utf-8')
      .str.replace('[^0-9a-zA-Z_]+', '_', regex=True)
      .str.replace('^[0-9]+', '', regex=True)
      .str.strip('_')
)

gdf_colunas = gdf_colunas.rename(columns={'': 'empty_field'})

gdf_colunas = gdf_colunas.rename(columns={
    'location_of_planned_interventio': 'planned_intervention',
    'intended_use_of_recycled_materi': 'use_of_recycled_material'
})

# Limitar cada nome a 31 caracteres
gdf_colunas.columns = [c[:31] for c in gdf_colunas.columns]

# %%
#Run locally and upload manually to ArcGIS the first time!
gdf_colunas.to_file("DWG_Gaza_Aggregate_for_Recycling.gpkg")

# %%
#### UPDATE DATA IN ARCGIS

#Connect to the ArcGIS Enterprise portal

AGOL_USERNAME = 'h.partow'
AGOL_PASSWORD = 'R&Runit2024'
gis = GIS('https://wesrmapportal.unep.org/portal/', AGOL_USERNAME, AGOL_PASSWORD)

# Access the feature-layer through its URL
file = "https://wesrmapportal.unep.org/arcgis/rest/services/Hosted/DWG_Gaza_Aggregate_for_Recycling/FeatureServer"

# Access the feature-layer through its URL
agg_file = 'DWG_Gaza_Aggregate_for_Recycling'

# %%
file

# %%
def searchArcgis(keyword):
    if not isinstance(keyword, str):
        raise TypeError(f"Esperado 'str' em 'keyword', recebido {type(keyword)} → {keyword}")
    results = gis.content.search(f'title:\"{keyword}\"', item_type="Feature Layer")
    if not results:
        print("Nenhum resultado encontrado para", keyword)
        return None
    results_sorted = sorted(results, key=lambda x: x.modified, reverse=True)
    return results_sorted[0]

search_agg = searchArcgis(agg_file)

# %%
def updateFeature(search_results, gdf):

    item = gis.content.get(search_results.id)

    flc = FeatureLayerCollection.fromitem(item)
    layer = flc.layers[0]  # Assuming you're working with the first layer


    # Step 1: Truncate features
    truncate_result = layer.manager.truncate()
    print("Truncate result:", truncate_result)

    # Keep only matching columns
    expected_fields = [f["name"] for f in layer.properties.fields if f["name"] != "fid"]
    gdf = gdf[[col for col in gdf.columns if col in expected_fields or col == "geometry"]]

    gdf = gdf.to_crs(epsg=4326)

    sedf = GeoAccessor.from_geodataframe(gdf)

    fs = FeatureSet.from_dataframe(sedf)

    result = layer.edit_features(adds=fs.features)
    print("Result:", result)
    return(result)

# %%
gdf_exploded.plot()

# %%
search_agg

# %%
updateFeature(search_agg, gdf_exploded)
# Out:
# Truncate result: {'success': True}
# Result: {'addResults': [{'success': True, 'objectId': 1}, {'success': True, 'objectId': 2}, {'success': True, 'objectId': 3}, {'success': True, 'objectId': 4}, {'success': True, 'objectId': 5}, {'success': True, 'objectId': 6}, {'success': True, 'objectId': 7}, {'success': True, 'objectId': 8}, {'success': True, 'objectId': 9}, {'success': True, 'objectId': 10}, {'success': True, 'objectId': 11}, {'success': True, 'objectId': 12}, {'success': True, 'objectId': 13}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'success': True, 'objectId': 1},
#   {'success': True, 'objectId': 2},
#   {'success': True, 'objectId': 3},
#   {'success': True, 'objectId': 4},
#   {'success': True, 'objectId': 5},
#   {'success': True, 'objectId': 6},
#   {'success': True, 'objectId': 7},
#   {'success': True, 'objectId': 8},
#   {'success': True, 'objectId': 9},
#   {'success': True, 'objectId': 10},
#   {'success': True, 'objectId': 11},
#   {'success': True, 'objectId': 12},
#   {'success': True, 'objectId': 13}],
#  'updateResults': [],
#  'deleteResults': []}
