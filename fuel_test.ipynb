# %%
# import requirements 
import requests
import re
import pandas as pd
import geopandas as gpd
from arcgis.gis import GIS
import os
import numpy as np
from arcgis.features import FeatureLayerCollection
from arcgis.features import FeatureSet, GeoAccessor
from arcgis.geometry import Geometry

# %%
#Import external files
governorate_municipality = gpd.read_file("UNEP_Gaza_Governorate_Municipality_Singleparts_POINTS.gpkg")
governorate_municipality = governorate_municipality.to_crs(epsg=4326)
governorate_municipality.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#Read this to know more about how Kobo handles synchronous exports and where to find the right url
#https://support.kobotoolbox.org/synchronous_exports.html

#### FETCH KOBO DATA

# Authentication credentials
KOBO_USERNAME = "guilherme_iablonovski"
KOBO_PASSWORD = "k0b0Senha"
export_token = "f72722c6ffe97db14144325853528a4b7a1c059b"

#Fuel Request API endpoint
kobo_api_url = "https://kf.kobotoolbox.org/api/v2/assets/aYyrjnacEdnBdZnXaxMcG5/export-settings/eskV2HM9SKSUw6pB93aZqWK"

# %%
def getKoboForm(url):
    # Create a session with authentication
    session = requests.Session()
    session.auth = (KOBO_USERNAME, KOBO_PASSWORD)

    # Construct the export URL
    kobo_export_url = f"{url}/data.xlsx"#?format=csv&token={export_token}"

    # Fetch data using the authenticated session
    response = session.get(kobo_export_url)

    # Check if the request was successful
    if response.status_code == 200:
        # Load data into a pandas DataFrame
        kobo_data = pd.read_excel(response.content)
        kobo_data.head()
        return kobo_data
    else:
        print("Error:", response.status_code)
        
kobo_data = getKoboForm(kobo_api_url)
# Out:
# C:\Users\joses\AppData\Local\Temp\ipykernel_16136\399000899.py:15: FutureWarning: Passing bytes to 'read_excel' is deprecated and will be removed in a future version. To read from a byte string, wrap it in a `BytesIO` object.
#   kobo_data = pd.read_excel(response.content)

# %%
kobo_data
# Out:
#     This note can be read out loud  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
#
#     Please fill in this form if you represent a non-government organisation requesting fuel for debris removal purposes.  \
# 0                                                                                                                    NaN
# 1                                                                                                                    NaN
# 2                                                                                                                    NaN
# 3                                                                                                                    NaN
# 4                                                                                                                    NaN
# 5                                                                                                                    NaN
# 6                                                                                                                    NaN
# 7                                                                                                                    NaN
# 8                                                                                                                    NaN
# 9                                                                                                                    NaN
# 10                                                                                                                   NaN
# 11                                                                                                                   NaN
# 12                                                                                                                   NaN
# 13                                                                                                                   NaN
# 14                                                                                                                   NaN
# 15                                                                                                                   NaN
# 16                                                                                                                   NaN
# 17                                                                                                                   NaN
# 18                                                                                                                   NaN
# 19                                                                                                                   NaN
# 20                                                                                                                   NaN
# 21                                                                                                                   NaN
# 22                                                                                                                   NaN
#
#    Implementing agency                 Please specify  Contact person name  \
# 0                  NaN                            NaN                  NaN
# 1                  NaN                            NaN                  NaN
# 2                  NaN                            NaN                  NaN
# 3                  NaN                            NaN                  NaN
# 4                  NaN                            NaN                  NaN
# 5                  NaN                            NaN                  NaN
# 6                  NaN                            NaN                  NaN
# 7                  NaN                            NaN                  NaN
# 8                  NaN                            NaN                  NaN
# 9                  NaN                            NaN                  NaN
# 10                UNDP                            NaN  Mohammed Abu Mezyed
# 11               Other                          AIOCP        Ahmed alghuff
# 12               Other        AIOCP-gaza municipality        Ahmed alghuff
# 13               Other                  AIOCP-jabalia        Ahmed alghuff
# 14                UNDP                            NaN  Mohammed Abu Mezyed
# 15               Other  AIOCP-khanyounes municipality        Ahmed alghuff
# 16               Other             Egyptian Committee          Ahmed Zakri
# 17               AIOCP                            NaN       ahmed al ghuff
# 18               AIOCP                            NaN       ahmed al ghuff
# 19               AIOCP                            NaN       ahmed al ghuff
# 20               AIOCP                            NaN       ahmed al ghuff
# 21               AIOCP                            NaN       ahmed al ghuff
# 22                 IOM                            NaN                 test
#
#                      Contact person phone number Contact person email address  \
# 0                                            NaN                          NaN
# 1                                            NaN                          NaN
# 2                                            NaN                          NaN
# 3                                            NaN                          NaN
# 4                                            NaN                          NaN
# 5                                            NaN                          NaN
# 6                                            NaN                          NaN
# 7                                            NaN                          NaN
# 8                                            NaN                          NaN
# 9                                            NaN                          NaN
# 10                                    0599800169     Mohammad.Mezyad@undp.org
# 11                                    0598120400       Ahmedghuff@palimar.org
# 12                                    0598120400       Ahmedghuff@palimar.org
# 13                                    0598120400     Ahmedalghuff@palimar.org
# 14  Chief Technical Specialist-Debris Management     mohammad.mezyad@undp.org
# 15                                    0598120400       Ahmedghuff@palimar.org
# 16                                 +970595596020         xahmad1105@gmail.com
# 17                                    0598120400       ahmedghuff@palimar.org
# 18                                    0598120400       ahmedghuff@palimar.org
# 19                                    0598120400       ahmedghuff@palimar.org
# 20                                    0598120400       ahmedghuff@palimar.org
# 21                                    0598120400       ahmedghuff@palimar.org
# 22                                          test                         test
#
#    Do you have a MoU with UNOPS?  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           Yes
# 11                           Yes
# 12                           Yes
# 13                           Yes
# 14                           Yes
# 15                           Yes
# 16                            No
# 17                           Yes
# 18                           Yes
# 19                           Yes
# 20                           Yes
# 21                           Yes
# 22                           Yes
#
#                 Location of planned intervention(s)  \
# 0                                     Deir Al-Balah
# 1                                       Khan Younis
# 2                         Deir Al-Balah Khan Younis
# 3                                   Gaza North Gaza
# 4                       Gaza Khan Younis North Gaza
# 5                    Deir Al-Balah Gaza Khan Younis
# 6                    Deir Al-Balah Gaza Khan Younis
# 7                       Gaza Khan Younis North Gaza
# 8                                       Khan Younis
# 9                                              Gaza
# 10                   Deir Al-Balah Gaza Khan Younis
# 11                      Gaza Khan Younis North Gaza
# 12                                             Gaza
# 13                                       North Gaza
# 14                   Deir Al-Balah Gaza Khan Younis
# 15                                      Khan Younis
# 16                                              NaN
# 17                      Gaza Khan Younis North Gaza
# 18                                             Gaza
# 19                                       North Gaza
# 20                                      Khan Younis
# 21                                       North Gaza
# 22  Deir Al-Balah Gaza Khan Younis North Gaza Rafah
#
#                                                           Please specify the municipality (Deir Al-Balah)  \
# 0                                                                                          Deir al Balah.
# 1                                                                                                     NaN
# 2                                                                                          Deir al Balah.
# 3                                                                                                     NaN
# 4                                                                                                     NaN
# 5              Al Bureij. Al Maghazi. Al Musaddar. An Nuseirat. Az Zawayda. Deir al Balah. Wadi as Salqa.
# 6   Al Bureij. Al Maghazi. Al Musaddar. Al Qarara. An Nuseirat. Az Zawayda. Deir al Balah. Wadi as Salqa.
# 7                                                                                                     NaN
# 8                                                                                                     NaN
# 9                                                                                                     NaN
# 10                                                                                         Deir al Balah.
# 11                                                                                                    NaN
# 12                                                                                                    NaN
# 13                                                                                                    NaN
# 14                                                              Az Zawayda. Deir al Balah. Wadi as Salqa.
# 15                                                                                                    NaN
# 16                                                                                                    NaN
# 17                                                                                                    NaN
# 18                                                                                                    NaN
# 19                                                                                                    NaN
# 20                                                                                                    NaN
# 21                                                                                                    NaN
# 22  Al Bureij. Al Maghazi. Al Musaddar. Al Qarara. An Nuseirat. Az Zawayda. Deir al Balah. Wadi as Salqa.
#
#                              Please specify the municipality (Gaza)  \
# 0                                                               NaN
# 1                                                               NaN
# 2                                                               NaN
# 3                                                             Gaza.
# 4                                            Ash Shati' Camp. Gaza.
# 5                                                             Gaza.
# 6                                                             Gaza.
# 7                                            Ash Shati' Camp. Gaza.
# 8                                                               NaN
# 9                                            Ash Shati' Camp. Gaza.
# 10                                                            Gaza.
# 11                                                            Gaza.
# 12                                           Ash Shati' Camp. Gaza.
# 13                                                              NaN
# 14                                                            Gaza.
# 15                                                              NaN
# 16                                                              NaN
# 17                           Ash Shati' Camp. Gaza. Madinat Ezahra.
# 18                                           Ash Shati' Camp. Gaza.
# 19                                                              NaN
# 20                                                              NaN
# 21                                                              NaN
# 22  Al Bureij. Ash Shati' Camp. Gaza. Juhor ad Dik. Madinat Ezahra.
#
#                                                  Please specify the municipality (Khan Younis)  \
# 0                                                                                          NaN
# 1                                                                                  Khan Yunis.
# 2                                                                                  Khan Yunis.
# 3                                                                                          NaN
# 4                                                                                  Khan Yunis.
# 5                                                                       Al Qarara. Khan Yunis.
# 6                                                                       Al Qarara. Khan Yunis.
# 7                                                                                  Khan Yunis.
# 8                                                                                  Khan Yunis.
# 9                                                                                          NaN
# 10                                                                      Al Qarara. Khan Yunis.
# 11                                                                                 Khan Yunis.
# 12                                                                                         NaN
# 13                                                                                         NaN
# 14                                                                      Al Qarara. Khan Yunis.
# 15                                                                                 Khan Yunis.
# 16                                                                                         NaN
# 17                                                                                 Khan Yunis.
# 18                                                                                         NaN
# 19                                                                                         NaN
# 20                                                                                 Khan Yunis.
# 21                                                                                         NaN
# 22  Abasan al Kabira. Al Fukhkhari. Al Qarara. Al-Nnaser (Al Bayuk). Bani Suheila. Khan Yunis.
#
#       Please specify the municipality (North Gaza)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                            Beit Lahiya. Jabalya.
# 4                                         Jabalya.
# 5                                              NaN
# 6                                              NaN
# 7                                         Jabalya.
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                        Jabalya.
# 12                                             NaN
# 13                                        Jabalya.
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                           Beit Lahiya. Jabalya.
# 18                                             NaN
# 19                                        Jabalya.
# 20                                             NaN
# 21                                    Beit Lahiya.
# 22  Beit Hanun. Beit Lahiya. Jabalya. Um Al-NASER.
#
#          Please specify the municipality (Rafah)           Type of site  \
# 0                                            NaN                   Road
# 1                                            NaN                   Road
# 2                                            NaN                   Road
# 3                                            NaN                   Road
# 4                                            NaN                   Road
# 5                                            NaN                   Road
# 6                                            NaN                   Road
# 7                                            NaN                   Road
# 8                                            NaN                   Road
# 9                                            NaN                   Road
# 10                                           NaN  Road Public buildings
# 11                                           NaN                   Road
# 12                                           NaN                   Road
# 13                                           NaN                   Road
# 14                                           NaN  Road Public buildings
# 15                                           NaN                   Road
# 16                                           NaN                    NaN
# 17                                           NaN                   Road
# 18                                           NaN                   Road
# 19                                           NaN                   Road
# 20                                           NaN                   Road
# 21                                           NaN                   Road
# 22  Al-Nnaser (Al Bayuk). Rafah. Shokat as Sufi.                   Road
#
#                                                           Please, specify  \
# 0                                                                     NaN
# 1                                                                     NaN
# 2                                                                     NaN
# 3                                                                     NaN
# 4                                                                     NaN
# 5                                                                     NaN
# 6                                                                     NaN
# 7                                                                     NaN
# 8                                                                     NaN
# 9                                                                     NaN
# 10  opening the closed roads to facilitate the residents movement and DPs
# 11                                                                    NaN
# 12                                                                    NaN
# 13                                                                    NaN
# 14                                                                    NaN
# 15                                                                    NaN
# 16                                                                    NaN
# 17                                                           road opening
# 18                                                          roads opening
# 19                                                                    NaN
# 20                                                                    NaN
# 21                                                                    NaN
# 22                                                                   test
#
#                                                                                                                                Please describe the site  \
# 0                                                                                                                    clean the roads and open the roads
# 1                                                        Removal of debris from the closed Roads to facilitate the movement for humanitarian activities
# 2   All sites in Deir al-Balah and Khan Younis are public streets that urgently require rubble clearance to restore safe and easy access for residents.
# 3                                                                                                                                                   NaN
# 4                                                                                                                                                   NaN
# 5                                         Reason for demolition / debris removal: opening the closed roads to facilitate the residents movement and DPs
# 6                                                                             1.\topening the closed roads to facilitate the residents movement and DPs
# 7                                                                                                                                                   NaN
# 8                                                                                                                                                   NaN
# 9                                                                                                                                                   NaN
# 10                                                                                                Hospitales, schools and Roads that blocked by rubbles
# 11                                                                                                                                                Roads
# 12                                                                                                                                                Roads
# 13                                                                                                                                                Roads
# 14                                                                                        opening the closed roads to facilitate the residents movement
# 15                                                                                                                                                Roads
# 16                                                                                                                                                  NaN
# 17                                                                                                                                                roads
# 18                                                                                                                                                roads
# 19                                                                                                                                                roads
# 20                                                                                                                                                roads
# 21                                                                                                                                                roads
# 22                                                                                                                                                 test
#
#                                                                                   Scope of operation  \
# 0                                                                                                NaN
# 1                                                                                                NaN
# 2                                                                                                NaN
# 3                                                                                                NaN
# 4                                                                                                NaN
# 5                                                                                                NaN
# 6                                                                                                NaN
# 7                                                                                                NaN
# 8                                                                                                NaN
# 9                                                                                                NaN
# 10  Road opening (e.g., pushing debris to the roadside) Debris removal and disposal Debris recycling
# 11                   Road opening (e.g., pushing debris to the roadside) Debris removal and disposal
# 12                                               Road opening (e.g., pushing debris to the roadside)
# 13                                               Road opening (e.g., pushing debris to the roadside)
# 14  Road opening (e.g., pushing debris to the roadside) Debris removal and disposal Debris recycling
# 15                                               Road opening (e.g., pushing debris to the roadside)
# 16                                                                                               NaN
# 17                   Road opening (e.g., pushing debris to the roadside) Debris removal and disposal
# 18                                               Road opening (e.g., pushing debris to the roadside)
# 19                                               Road opening (e.g., pushing debris to the roadside)
# 20                                               Road opening (e.g., pushing debris to the roadside)
# 21                                               Road opening (e.g., pushing debris to the roadside)
# 22                                               Road opening (e.g., pushing debris to the roadside)
#
#     Estimated quantity of debris to be removed   Measurement unit  \
# 0                                        300.0  Metric tonnes (t)
# 1                                      90000.0  Metric tonnes (t)
# 2                                      34500.0  Metric tonnes (t)
# 3                                      70000.0                NaN
# 4                                       3000.0                NaN
# 5                                       9000.0  Metric tonnes (t)
# 6                                       9000.0  Metric tonnes (t)
# 7                                       3000.0  Cubic meters (m³)
# 8                                       1000.0  Cubic meters (m³)
# 9                                       2000.0  Cubic meters (m³)
# 10                                      9000.0  Metric tonnes (t)
# 11                                    100000.0  Cubic meters (m³)
# 12                                     32000.0  Cubic meters (m³)
# 13                                     20000.0  Cubic meters (m³)
# 14                                     70000.0  Metric tonnes (t)
# 15                                     24000.0  Cubic meters (m³)
# 16                                         NaN                NaN
# 17                                     72000.0  Cubic meters (m³)
# 18                                     48000.0  Cubic meters (m³)
# 19                                     24000.0  Cubic meters (m³)
# 20                                     32000.0  Cubic meters (m³)
# 21                                     16000.0  Cubic meters (m³)
# 22                                         1.0  Metric tonnes (t)
#
#     Liters of diesel required per week for debris removal and recycling purposes in North Gaza (North Gaza & Gaza City)  \
# 0                                                                                                                 500.0
# 1                                                                                                              135000.0
# 2                                                                                                               38352.0
# 3                                                                                                                   NaN
# 4                                                                                                                   NaN
# 5                                                                                                                   NaN
# 6                                                                                                               42000.0
# 7                                                                                                                   NaN
# 8                                                                                                                   NaN
# 9                                                                                                                   NaN
# 10                                                                                                              28000.0
# 11                                                                                                              60000.0
# 12                                                                                                              32000.0
# 13                                                                                                              20000.0
# 14                                                                                                              62500.0
# 15                                                                                                                  0.0
# 16                                                                                                                  NaN
# 17                                                                                                              12000.0
# 18                                                                                                              48000.0
# 19                                                                                                              24000.0
# 20                                                                                                                  0.0
# 21                                                                                                              16000.0
# 22                                                                                                                  1.0
#
#     Liters of diesel required per week for debris removal and recycling purposes in South Gaza (Deir Al-Balah, Khan Younis & Rafah)  \
# 0                                                                                                                               NaN
# 1                                                                                                                               NaN
# 2                                                                                                                               NaN
# 3                                                                                                                               NaN
# 4                                                                                                                               NaN
# 5                                                                                                                               NaN
# 6                                                                                                                               NaN
# 7                                                                                                                               NaN
# 8                                                                                                                               NaN
# 9                                                                                                                               NaN
# 10                                                                                                                          14000.0
# 11                                                                                                                          32000.0
# 12                                                                                                                              0.0
# 13                                                                                                                              0.0
# 14                                                                                                                         112500.0
# 15                                                                                                                          24000.0
# 16                                                                                                                              NaN
# 17                                                                                                                           6000.0
# 18                                                                                                                              0.0
# 19                                                                                                                              0.0
# 20                                                                                                                          32000.0
# 21                                                                                                                              0.0
# 22                                                                                                                              1.0
#
#                                                                                                                       Comments  \
# 0                                                                                                                          NaN
# 1                                                                                                                          NaN
# 2                                                                                                                          NaN
# 3                                                                                                                          NaN
# 4                                                                                                                          NaN
# 5                                                                                                                          NaN
# 6                                                                                                                          NaN
# 7                                                                                                                          NaN
# 8                                                                                                                          NaN
# 9                                                                                                                          NaN
# 10                                                                                                                         NaN
# 11                                                                                                                         NaN
# 12                                                                                                                         NaN
# 13                                                                                                                         NaN
# 14  for Gaza we need weekly around : 15,625 liters, and for Dair Albalah and Khan younis we need weekly around : 28,125 liters
# 15                                                                                                                         NaN
# 16                                                                                                                         NaN
# 17                                                                                                                         NaN
# 18                                                                                                                         NaN
# 19                                                                                                                         NaN
# 20                                                                                                                         NaN
# 21                                                                                                                         NaN
# 22                                                                                                                        test
#
#     Click on the Validate button below to send your response. Plase visit the Gaza DWG Website to find the responses to this form on the dashboards available.  \
# 0                                                                                                                                                          NaN
# 1                                                                                                                                                          NaN
# 2                                                                                                                                                          NaN
# 3                                                                                                                                                          NaN
# 4                                                                                                                                                          NaN
# 5                                                                                                                                                          NaN
# 6                                                                                                                                                          NaN
# 7                                                                                                                                                          NaN
# 8                                                                                                                                                          NaN
# 9                                                                                                                                                          NaN
# 10                                                                                                                                                         NaN
# 11                                                                                                                                                         NaN
# 12                                                                                                                                                         NaN
# 13                                                                                                                                                         NaN
# 14                                                                                                                                                         NaN
# 15                                                                                                                                                         NaN
# 16                                                                                                                                                         NaN
# 17                                                                                                                                                         NaN
# 18                                                                                                                                                         NaN
# 19                                                                                                                                                         NaN
# 20                                                                                                                                                         NaN
# 21                                                                                                                                                         NaN
# 22                                                                                                                                                         NaN
#
#     Please contact UNOPS for details on agreeing an MoU for fuel deliveries.  \
# 0                                                                        NaN
# 1                                                                        NaN
# 2                                                                        NaN
# 3                                                                        NaN
# 4                                                                        NaN
# 5                                                                        NaN
# 6                                                                        NaN
# 7                                                                        NaN
# 8                                                                        NaN
# 9                                                                        NaN
# 10                                                                       NaN
# 11                                                                       NaN
# 12                                                                       NaN
# 13                                                                       NaN
# 14                                                                       NaN
# 15                                                                       NaN
# 16                                                                       NaN
# 17                                                                       NaN
# 18                                                                       NaN
# 19                                                                       NaN
# 20                                                                       NaN
# 21                                                                       NaN
# 22                                                                       NaN
#
#           _id                                 _uuid    _submission_time  \
# 0   509204309  5e99250e-4ebf-401b-b913-344d9b453967 2025-07-02 13:43:58
# 1   509613833  b3021b66-fc42-441a-bd1f-a8704aadc8d1 2025-07-03 06:33:49
# 2   554713303  c9d9d7dc-3feb-49fc-9a92-67af1172e501 2025-09-09 07:08:43
# 3   580205978  98abb206-0760-4eff-add7-9b2f3b662bd1 2025-10-11 15:38:18
# 4   584623219  110bdf70-e4a5-44ee-9911-91a1bb328b19 2025-10-17 10:32:21
# 5   584657848  249825ad-e692-4bf5-a76a-5d424acf7e20 2025-10-17 11:17:45
# 6   584680179  7f67fb6a-3ccd-4d7d-841f-e35fdcc5be16 2025-10-17 11:46:53
# 7   588789860  d747f52f-d85b-4247-aba2-2c6ad214b784 2025-10-23 05:15:21
# 8   588791570  920d79ec-c687-4567-9c50-8c43567cbe38 2025-10-23 05:19:36
# 9   588792542  607a0e99-6337-43fa-b563-ceb09f1ec054 2025-10-23 05:21:27
# 10  588865776  84a76928-f6b4-4d23-a816-bb9908b8f4c8 2025-10-23 07:22:19
# 11  593842372  fa985f61-df30-4240-800c-9d2dffa2f46b 2025-10-29 18:02:01
# 12  593843798  b1bbcda9-7633-4f13-80f9-ef806b3f574c 2025-10-29 18:04:36
# 13  593845053  e1ab52fc-9700-4082-acdf-228da1aa3f85 2025-10-29 18:06:37
# 14  594126958  fc69fc56-f83a-42d7-9286-e581112826ad 2025-10-30 06:38:03
# 15  596239852  8b707bce-7bab-45b1-8a0b-e8a865335851 2025-11-02 06:10:20
# 16  600078169  540230b2-01a8-4ff1-bc14-21d934c3c987 2025-11-06 19:04:42
# 17  603900307  df479171-bc9a-4ad1-8459-0f602f297248 2025-11-12 09:26:49
# 18  603901745  2c46726e-ccb1-4379-9d0f-020e165fcac6 2025-11-12 09:28:11
# 19  603902413  b0597b75-1f4e-4387-9c65-439effc5c8ac 2025-11-12 09:28:54
# 20  603903320  3049b76a-0f10-446d-bc26-043f5f4b6024 2025-11-12 09:30:01
# 21  603903975  6b638b18-0492-4e0f-a7e5-a56fc2f34295 2025-11-12 09:30:51
# 22  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
#
#     _validation_status  _notes            _status  _submitted_by  \
# 0                  NaN     NaN  submitted_via_web            NaN
# 1                  NaN     NaN  submitted_via_web            NaN
# 2                  NaN     NaN  submitted_via_web            NaN
# 3                  NaN     NaN  submitted_via_web            NaN
# 4                  NaN     NaN  submitted_via_web            NaN
# 5                  NaN     NaN  submitted_via_web            NaN
# 6                  NaN     NaN  submitted_via_web            NaN
# 7                  NaN     NaN  submitted_via_web            NaN
# 8                  NaN     NaN  submitted_via_web            NaN
# 9                  NaN     NaN  submitted_via_web            NaN
# 10                 NaN     NaN  submitted_via_web            NaN
# 11                 NaN     NaN  submitted_via_web            NaN
# 12                 NaN     NaN  submitted_via_web            NaN
# 13                 NaN     NaN  submitted_via_web            NaN
# 14                 NaN     NaN  submitted_via_web            NaN
# 15                 NaN     NaN  submitted_via_web            NaN
# 16                 NaN     NaN  submitted_via_web            NaN
# 17                 NaN     NaN  submitted_via_web            NaN
# 18                 NaN     NaN  submitted_via_web            NaN
# 19                 NaN     NaN  submitted_via_web            NaN
# 20                 NaN     NaN  submitted_via_web            NaN
# 21                 NaN     NaN  submitted_via_web            NaN
# 22                 NaN     NaN  submitted_via_web            NaN
#
#                __version__  _tags  _index
# 0   vrUo2zbbGfNkhDf8V63RcD    NaN       1
# 1   vrUo2zbbGfNkhDf8V63RcD    NaN       2
# 2   vn3LwfJj9CHwtUAVPUauxa    NaN       3
# 3   vaY28MWx3PuyJsMiDtRXix    NaN       4
# 4   v9j7GrtCx8DU3Tgt3p5HED    NaN       5
# 5   v9j7GrtCx8DU3Tgt3p5HED    NaN       6
# 6   vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 7   v9j7GrtCx8DU3Tgt3p5HED    NaN       8
# 8   v9j7GrtCx8DU3Tgt3p5HED    NaN       9
# 9   v9j7GrtCx8DU3Tgt3p5HED    NaN      10
# 10  vvU2Bg4uP9fRRZLbJyMvKn    NaN      11
# 11  vFMPfevk3YYzmYrGVjsriB    NaN      12
# 12  vFMPfevk3YYzmYrGVjsriB    NaN      13
# 13  vFMPfevk3YYzmYrGVjsriB    NaN      14
# 14  vvTrAibjDz3pTeScPNavsX    NaN      15
# 15  vFMPfevk3YYzmYrGVjsriB    NaN      16
# 16  vRN8bzjcij4TyUXBx5vhfN    NaN      17
# 17  vRN8bzjcij4TyUXBx5vhfN    NaN      18
# 18  vRN8bzjcij4TyUXBx5vhfN    NaN      19
# 19  vRN8bzjcij4TyUXBx5vhfN    NaN      20
# 20  vRN8bzjcij4TyUXBx5vhfN    NaN      21
# 21  vRN8bzjcij4TyUXBx5vhfN    NaN      22
# 22  vRN8bzjcij4TyUXBx5vhfN    NaN      23

# %%
# Identifica as colunas que começam com "Please specify the municipality"
cols = [c for c in kobo_data.columns if c.startswith("Please specify the municipality")]

# Cria uma lista para armazenar os registros explodidos
records = []

# Itera sobre cada linha e coluna dessas
for _, row in kobo_data.iterrows():
    base_data = {col: row[col] for col in kobo_data.columns if col not in cols}  # mantém outras colunas

    for col in cols:
        val = row[col]
        if pd.isna(val):
            continue

        # Extrai o nome entre parênteses
        match = re.search(r'\((.*?)\)', col)
        governo = match.group(1).strip() if match else ''

        # Divide as respostas usando ". " como separador
        municipios = re.split(r'(?<=\.)\s+', str(val).strip())

        # Limpa e forma a nova lista com "Governo_Município"
        for m in municipios:
            m = m.strip().rstrip('.')
            if m:
                new_row = base_data.copy()
                new_row['Gov_Mun'] = f"{governo}_{m}"
                records.append(new_row)

# Cria o novo DataFrame com as linhas expandidas
kobo_data_exploded = pd.DataFrame(records).reset_index(drop=True)

# %%
kobo_data_exploded
# Out:
#     This note can be read out loud  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 88                             NaN
# 89                             NaN
# 90                             NaN
# 91                             NaN
# 92                             NaN
#
#     Please fill in this form if you represent a non-government organisation requesting fuel for debris removal purposes.  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
# 92                                                NaN
#
#    Implementing agency Please specify Contact person name  \
# 0                  NaN            NaN                 NaN
# 1                  NaN            NaN                 NaN
# 2                  NaN            NaN                 NaN
# 3                  NaN            NaN                 NaN
# 4                  NaN            NaN                 NaN
# ..                 ...            ...                 ...
# 88                 IOM            NaN                test
# 89                 IOM            NaN                test
# 90                 IOM            NaN                test
# 91                 IOM            NaN                test
# 92                 IOM            NaN                test
#
#    Contact person phone number Contact person email address  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# ..                         ...                          ...
# 88                        test                         test
# 89                        test                         test
# 90                        test                         test
# 91                        test                         test
# 92                        test                         test
#
#    Do you have a MoU with UNOPS?  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 88                           Yes
# 89                           Yes
# 90                           Yes
# 91                           Yes
# 92                           Yes
#
#                 Location of planned intervention(s) Type of site  ...  \
# 0                                     Deir Al-Balah         Road  ...
# 1                                       Khan Younis         Road  ...
# 2                         Deir Al-Balah Khan Younis         Road  ...
# 3                         Deir Al-Balah Khan Younis         Road  ...
# 4                                   Gaza North Gaza         Road  ...
# ..                                              ...          ...  ...
# 88  Deir Al-Balah Gaza Khan Younis North Gaza Rafah         Road  ...
# 89  Deir Al-Balah Gaza Khan Younis North Gaza Rafah         Road  ...
# 90  Deir Al-Balah Gaza Khan Younis North Gaza Rafah         Road  ...
# 91  Deir Al-Balah Gaza Khan Younis North Gaza Rafah         Road  ...
# 92  Deir Al-Balah Gaza Khan Younis North Gaza Rafah         Road  ...
#
#                                    _uuid    _submission_time  \
# 0   5e99250e-4ebf-401b-b913-344d9b453967 2025-07-02 13:43:58
# 1   b3021b66-fc42-441a-bd1f-a8704aadc8d1 2025-07-03 06:33:49
# 2   c9d9d7dc-3feb-49fc-9a92-67af1172e501 2025-09-09 07:08:43
# 3   c9d9d7dc-3feb-49fc-9a92-67af1172e501 2025-09-09 07:08:43
# 4   98abb206-0760-4eff-add7-9b2f3b662bd1 2025-10-11 15:38:18
# ..                                   ...                 ...
# 88  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 89  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 90  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 91  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 92  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
#
#    _validation_status  _notes            _status  _submitted_by  \
# 0                 NaN     NaN  submitted_via_web            NaN
# 1                 NaN     NaN  submitted_via_web            NaN
# 2                 NaN     NaN  submitted_via_web            NaN
# 3                 NaN     NaN  submitted_via_web            NaN
# 4                 NaN     NaN  submitted_via_web            NaN
# ..                ...     ...                ...            ...
# 88                NaN     NaN  submitted_via_web            NaN
# 89                NaN     NaN  submitted_via_web            NaN
# 90                NaN     NaN  submitted_via_web            NaN
# 91                NaN     NaN  submitted_via_web            NaN
# 92                NaN     NaN  submitted_via_web            NaN
#
#                __version__ _tags  _index                      Gov_Mun
# 0   vrUo2zbbGfNkhDf8V63RcD   NaN       1  Deir Al-Balah_Deir al Balah
# 1   vrUo2zbbGfNkhDf8V63RcD   NaN       2       Khan Younis_Khan Yunis
# 2   vn3LwfJj9CHwtUAVPUauxa   NaN       3  Deir Al-Balah_Deir al Balah
# 3   vn3LwfJj9CHwtUAVPUauxa   NaN       3       Khan Younis_Khan Yunis
# 4   vaY28MWx3PuyJsMiDtRXix   NaN       4                    Gaza_Gaza
# ..                     ...   ...     ...                          ...
# 88  vRN8bzjcij4TyUXBx5vhfN   NaN      23           North Gaza_Jabalya
# 89  vRN8bzjcij4TyUXBx5vhfN   NaN      23       North Gaza_Um Al-NASER
# 90  vRN8bzjcij4TyUXBx5vhfN   NaN      23   Rafah_Al-Nnaser (Al Bayuk)
# 91  vRN8bzjcij4TyUXBx5vhfN   NaN      23                  Rafah_Rafah
# 92  vRN8bzjcij4TyUXBx5vhfN   NaN      23         Rafah_Shokat as Sufi
#
# [93 rows x 31 columns]

# %%
#### INITIAL CLEANING

#Standardize data for municipalities without neighborhoods

def standardize(df):

    kobo_data_0 = df.replace(0, None)  
    return kobo_data_0

kobo_data_exploded = standardize(kobo_data_exploded)

# Faz o join com o gdf, mantendo todos os municípios originais

gdf_filtrado = governorate_municipality.merge(kobo_data_exploded, on='Gov_Mun', how='right')

# %%
gdf_filtrado.plot()
# Out:
# <Axes: >

# %%
pd.set_option("display.max_columns", None)  # mostra todas as colunas
pd.set_option("display.max_rows", None)     # mostra todas as linhas
pd.set_option("display.width", None)        # evita quebra de linha automática
pd.set_option("display.max_colwidth", None) # evita truncar valores longos

# %%
gdf_filtrado
# Out:
#     OBJECTID                      Neighborhood          Municipality  \
# 0       13.0                             Other         Deir al Balah
# 1       15.0                   Qizan An-Najjar            Khan Yunis
# 2       13.0                             Other         Deir al Balah
# 3       15.0                   Qizan An-Najjar            Khan Yunis
# 4       14.0                        Az Zaitoun                  Gaza
# 5        5.0                        Al Attarta           Beit Lahiya
# 6       26.0                 Ash Sheikh Radwan               Jabalya
# 7       25.0                    Northern Remal       Ash Shati' Camp
# 8       14.0                        Az Zaitoun                  Gaza
# 9       15.0                   Qizan An-Najjar            Khan Yunis
# 10      26.0                 Ash Sheikh Radwan               Jabalya
# 11      24.0                             Other             Al Bureij
# 12      17.0                   Al Maghazi Camp            Al Maghazi
# 13       4.0                       Al Basateen           Al Musaddar
# 14      27.0                  An Nuseirat Camp           An Nuseirat
# 15       9.0                             Ansar            Az Zawayda
# 16      13.0                             Other         Deir al Balah
# 17       2.0                      Abu Mgheiseb         Wadi as Salqa
# 18      14.0                        Az Zaitoun                  Gaza
# 19      22.0                             Other             Al Qarara
# 20      15.0                   Qizan An-Najjar            Khan Yunis
# 21      24.0                             Other             Al Bureij
# 22      17.0                   Al Maghazi Camp            Al Maghazi
# 23       4.0                       Al Basateen           Al Musaddar
# 24      21.0                            Smeiri             Al Qarara
# 25      27.0                  An Nuseirat Camp           An Nuseirat
# 26       9.0                             Ansar            Az Zawayda
# 27      13.0                             Other         Deir al Balah
# 28       2.0                      Abu Mgheiseb         Wadi as Salqa
# 29      14.0                        Az Zaitoun                  Gaza
# 30      22.0                             Other             Al Qarara
# 31      15.0                   Qizan An-Najjar            Khan Yunis
# 32      25.0                    Northern Remal       Ash Shati' Camp
# 33      14.0                        Az Zaitoun                  Gaza
# 34      15.0                   Qizan An-Najjar            Khan Yunis
# 35      26.0                 Ash Sheikh Radwan               Jabalya
# 36      15.0                   Qizan An-Najjar            Khan Yunis
# 37      25.0                    Northern Remal       Ash Shati' Camp
# 38      14.0                        Az Zaitoun                  Gaza
# 39      13.0                             Other         Deir al Balah
# 40      14.0                        Az Zaitoun                  Gaza
# 41      22.0                             Other             Al Qarara
# 42      15.0                   Qizan An-Najjar            Khan Yunis
# 43      14.0                        Az Zaitoun                  Gaza
# 44      15.0                   Qizan An-Najjar            Khan Yunis
# 45      26.0                 Ash Sheikh Radwan               Jabalya
# 46      25.0                    Northern Remal       Ash Shati' Camp
# 47      14.0                        Az Zaitoun                  Gaza
# 48      26.0                 Ash Sheikh Radwan               Jabalya
# 49       9.0                             Ansar            Az Zawayda
# 50      13.0                             Other         Deir al Balah
# 51       2.0                      Abu Mgheiseb         Wadi as Salqa
# 52      14.0                        Az Zaitoun                  Gaza
# 53      22.0                             Other             Al Qarara
# 54      15.0                   Qizan An-Najjar            Khan Yunis
# 55      15.0                   Qizan An-Najjar            Khan Yunis
# 56      25.0                    Northern Remal       Ash Shati' Camp
# 57      14.0                        Az Zaitoun                  Gaza
# 58       8.0                             Other        Madinat Ezahra
# 59      15.0                   Qizan An-Najjar            Khan Yunis
# 60       5.0                        Al Attarta           Beit Lahiya
# 61      26.0                 Ash Sheikh Radwan               Jabalya
# 62      25.0                    Northern Remal       Ash Shati' Camp
# 63      14.0                        Az Zaitoun                  Gaza
# 64      26.0                 Ash Sheikh Radwan               Jabalya
# 65      15.0                   Qizan An-Najjar            Khan Yunis
# 66       5.0                        Al Attarta           Beit Lahiya
# 67      24.0                             Other             Al Bureij
# 68      17.0                   Al Maghazi Camp            Al Maghazi
# 69       4.0                       Al Basateen           Al Musaddar
# 70      21.0                            Smeiri             Al Qarara
# 71      27.0                  An Nuseirat Camp           An Nuseirat
# 72       9.0                             Ansar            Az Zawayda
# 73      13.0                             Other         Deir al Balah
# 74       2.0                      Abu Mgheiseb         Wadi as Salqa
# 75       7.0                             Other             Al Bureij
# 76      25.0                    Northern Remal       Ash Shati' Camp
# 77      14.0                        Az Zaitoun                  Gaza
# 78      11.0                             Other          Juhor ad Dik
# 79       8.0                             Other        Madinat Ezahra
# 80       NaN                               NaN                   NaN
# 81       1.0                      Al Fukhkhari          Al Fukhkhari
# 82      22.0                             Other             Al Qarara
# 83      20.0                        Umm Kameil  Al-Nnaser (Al Bayuk)
# 84      23.0                      Bani Suheila          Bani Suheila
# 85      15.0                   Qizan An-Najjar            Khan Yunis
# 86       6.0                       Hai Al Amal            Beit Hanun
# 87       5.0                        Al Attarta           Beit Lahiya
# 88      26.0                 Ash Sheikh Radwan               Jabalya
# 89       3.0  Al Qaraya al Badawiya al Maslakh           Um Al-NASER
# 90      18.0                           An Nasr  Al-Nnaser (Al Bayuk)
# 91      16.0                             Other                 Rafah
# 92      12.0                             Other        Shokat as Sufi
#
#       Governorate   Shape__Area  Shape__Length ArabicName governate_name  \
# 0   Deir Al-Balah  9.349202e+06   30255.114321       None  deir_al_balah
# 1     Khan Younis  2.106340e+07   62495.791756       None    khan_younis
# 2   Deir Al-Balah  9.349202e+06   30255.114321       None  deir_al_balah
# 3     Khan Younis  2.106340e+07   62495.791756       None    khan_younis
# 4            Gaza  2.022278e+07   32744.382215       None           gaza
# 5      North Gaza  4.938257e+06   12707.141053       None     north_gaza
# 6      North Gaza  6.588842e+06   20753.944642       None     north_gaza
# 7            Gaza  4.312410e+05    4724.319434       None           gaza
# 8            Gaza  2.022278e+07   32744.382215       None           gaza
# 9     Khan Younis  2.106340e+07   62495.791756       None    khan_younis
# 10     North Gaza  6.588842e+06   20753.944642       None     north_gaza
# 11  Deir Al-Balah  8.915514e+06   23504.738364       None  deir_al_balah
# 58           Gaza  8.744942e+06   17099.858596       None           gaza
# 59    Khan Younis  2.106340e+07   62495.791756       None    khan_younis
# 60     North Gaza  4.938257e+06   12707.141053       None     north_gaza
# 61     North Gaza  6.588842e+06   20753.944642       None     north_gaza
# 62           Gaza  4.312410e+05    4724.319434       None           gaza
# 63           Gaza  2.022278e+07   32744.382215       None           gaza
# 64     North Gaza  6.588842e+06   20753.944642       None     north_gaza
# 65    Khan Younis  2.106340e+07   62495.791756       None    khan_younis
# 66     North Gaza  4.938257e+06   12707.141053       None     north_gaza
# 67  Deir Al-Balah  8.915514e+06   23504.738364       None  deir_al_balah
# 68  Deir Al-Balah  7.870304e+05    4872.763653       None  deir_al_balah
# 69  Deir Al-Balah  1.565272e+06    7815.068901       None  deir_al_balah
# 70  Deir Al-Balah  7.619508e+06   22440.383384       None  deir_al_balah
# 71  Deir Al-Balah  1.694287e+06    6549.603188       None  deir_al_balah
# 72  Deir Al-Balah  7.660522e+06   18064.708557       None  deir_al_balah
# 73  Deir Al-Balah  9.349202e+06   30255.114321       None  deir_al_balah
# 74  Deir Al-Balah  1.875443e+06    6378.072751       None  deir_al_balah
# 75           Gaza  4.641780e+06   14448.289435       None           gaza
# 76           Gaza  4.312410e+05    4724.319434       None           gaza
# 77           Gaza  2.022278e+07   32744.382215       None           gaza
# 78           Gaza  1.502207e+07   25386.550760       None           gaza
# 79           Gaza  8.744942e+06   17099.858596       None           gaza
# 80            NaN           NaN            NaN        NaN            NaN
# 81    Khan Younis  2.303302e+05    2161.057834       None    khan_younis
# 82    Khan Younis  7.619508e+06   22440.383384       None    khan_younis
# 83    Khan Younis  5.372368e+05    3454.599802       None    khan_younis
# 84    Khan Younis  2.631701e+06    9507.350475       None    khan_younis
# 85    Khan Younis  2.106340e+07   62495.791756       None    khan_younis
# 86     North Gaza  8.140580e+06   12980.393705       None     north_gaza
# 87     North Gaza  4.938257e+06   12707.141053       None     north_gaza
# 88     North Gaza  6.588842e+06   20753.944642       None     north_gaza
# 89     North Gaza  2.287709e+06    6929.079613       None     north_gaza
# 90          Rafah  3.430277e+05    2553.911622       None          rafah
# 91          Rafah  5.013233e+07   76811.585355       None          rafah
# 92          Rafah  1.987058e+07   26573.582395       None          rafah
#
#       municipality_name                 neighborhood_name  \
# 0         deir_al_balah                             other
# 1            khan_yunis                  qizan_an__najjar
# 2         deir_al_balah                             other
# 3            khan_yunis                  qizan_an__najjar
# 4                  gaza                        az_zaitoun
# 5           beit_lahiya                        al_attarta
# 6               jabalya                 ash_sheikh_radwan
# 7        ash_shati_camp                    northern_remal
# 8                  gaza                        az_zaitoun
# 9            khan_yunis                  qizan_an__najjar
# 10              jabalya                 ash_sheikh_radwan
# 11            al_bureij                             other
# 12           al_maghazi                   al_maghazi_camp
# 13          al_musaddar                       al_basateen
# 14          an_nuseirat                  an_nuseirat_camp
# 15           az_zawayda                             ansar
# 16        deir_al_balah                             other
# 17        wadi_as_salqa                      abu_mgheiseb
# 18                 gaza                        az_zaitoun
# 19            al_qarara                             other
# 20           khan_yunis                  qizan_an__najjar
# 21            al_bureij                             other
# 22           al_maghazi                   al_maghazi_camp
# 23          al_musaddar                       al_basateen
# 24            al_qarara                            smeiri
# 25          an_nuseirat                  an_nuseirat_camp
# 26           az_zawayda                             ansar
# 27        deir_al_balah                             other
# 28        wadi_as_salqa                      abu_mgheiseb
# 29                 gaza                        az_zaitoun
# 30            al_qarara                             other
# 31           khan_yunis                  qizan_an__najjar
# 32       ash_shati_camp                    northern_remal
# 33                 gaza                        az_zaitoun
# 34           khan_yunis                  qizan_an__najjar
# 35              jabalya                 ash_sheikh_radwan
# 36           khan_yunis                  qizan_an__najjar
# 37       ash_shati_camp                    northern_remal
# 38                 gaza                        az_zaitoun
# 39        deir_al_balah                             other
# 40                 gaza                        az_zaitoun
# 41            al_qarara                             other
# 42           khan_yunis                  qizan_an__najjar
# 43                 gaza                        az_zaitoun
# 44           khan_yunis                  qizan_an__najjar
# 45              jabalya                 ash_sheikh_radwan
# 46       ash_shati_camp                    northern_remal
# 47                 gaza                        az_zaitoun
# 48              jabalya                 ash_sheikh_radwan
# 49           az_zawayda                             ansar
# 50        deir_al_balah                             other
# 51        wadi_as_salqa                      abu_mgheiseb
# 52                 gaza                        az_zaitoun
# 53            al_qarara                             other
# 54           khan_yunis                  qizan_an__najjar
# 55           khan_yunis                  qizan_an__najjar
# 56       ash_shati_camp                    northern_remal
# 57                 gaza                        az_zaitoun
# 58       madinat_ezahra                             other
# 59           khan_yunis                  qizan_an__najjar
# 60          beit_lahiya                        al_attarta
# 61              jabalya                 ash_sheikh_radwan
# 62       ash_shati_camp                    northern_remal
# 63                 gaza                        az_zaitoun
# 64              jabalya                 ash_sheikh_radwan
# 65           khan_yunis                  qizan_an__najjar
# 66          beit_lahiya                        al_attarta
# 67            al_bureij                             other
# 68           al_maghazi                   al_maghazi_camp
# 69          al_musaddar                       al_basateen
# 70            al_qarara                            smeiri
# 71          an_nuseirat                  an_nuseirat_camp
# 72           az_zawayda                             ansar
# 73        deir_al_balah                             other
# 74        wadi_as_salqa                      abu_mgheiseb
# 75            al_bureij                             other
# 76       ash_shati_camp                    northern_remal
# 77                 gaza                        az_zaitoun
# 78         juhor_ad_dik                             other
# 79       madinat_ezahra                             other
# 80                  NaN                               NaN
# 81         al_fukhkhari                      al_fukhkhari
# 82            al_qarara                             other
# 83  al_nnaser_al_bayuk_                        umm_kameil
# 84         bani_suheila                      bani_suheila
# 85           khan_yunis                  qizan_an__najjar
# 86           beit_hanun                       hai_al_amal
# 87          beit_lahiya                        al_attarta
# 88              jabalya                 ash_sheikh_radwan
# 89         um_al_naser_  al_qaraya_al_badawiya_al_maslakh
# 90  al_nnaser_al_bayuk_                           an_nasr
# 91                rafah                             other
# 92       shokat_as_sufi                             other
#
#                                                    Location_gdf  \
# 0                         (Deir Al-Balah / Deir al Balah)/Other
# 1                    (Khan Younis / Khan Yunis)/Qizan An-Najjar
# 2                         (Deir Al-Balah / Deir al Balah)/Other
# 3                    (Khan Younis / Khan Yunis)/Qizan An-Najjar
# 4                                      (Gaza / Gaza)/Az Zaitoun
# 58               Gaza_Madinat Ezahra  POINT (34.40827 31.47446)
# 59            Khan Younis_Khan Yunis  POINT (34.29992 31.35075)
# 60            North Gaza_Beit Lahiya  POINT (34.50268 31.56083)
# 61                North Gaza_Jabalya   POINT (34.4822 31.53741)
# 62              Gaza_Ash Shati' Camp  POINT (34.44821 31.52623)
# 63                         Gaza_Gaza  POINT (34.45983 31.50103)
# 64                North Gaza_Jabalya   POINT (34.4822 31.53741)
# 65            Khan Younis_Khan Yunis  POINT (34.29992 31.35075)
# 66            North Gaza_Beit Lahiya  POINT (34.50268 31.56083)
# 67           Deir Al-Balah_Al Bureij  POINT (34.40559 31.42972)
# 68          Deir Al-Balah_Al Maghazi  POINT (34.38699 31.42405)
# 69         Deir Al-Balah_Al Musaddar  POINT (34.38568 31.41439)
# 70           Deir Al-Balah_Al Qarara  POINT (34.36872 31.38205)
# 71         Deir Al-Balah_An Nuseirat  POINT (34.39081 31.45264)
# 72          Deir Al-Balah_Az Zawayda  POINT (34.36975 31.43705)
# 73       Deir Al-Balah_Deir al Balah  POINT (34.34933 31.40774)
# 74       Deir Al-Balah_Wadi as Salqa   POINT (34.3612 31.39191)
# 75                    Gaza_Al Bureij  POINT (34.41727 31.44893)
# 76              Gaza_Ash Shati' Camp  POINT (34.44821 31.52623)
# 77                         Gaza_Gaza  POINT (34.45983 31.50103)
# 78                 Gaza_Juhor ad Dik  POINT (34.44222 31.45875)
# 79               Gaza_Madinat Ezahra  POINT (34.40827 31.47446)
# 80      Khan Younis_Abasan al Kabira                       None
# 81          Khan Younis_Al Fukhkhari  POINT (34.33681 31.28982)
# 82             Khan Younis_Al Qarara  POINT (34.35301 31.37446)
# 83  Khan Younis_Al-Nnaser (Al Bayuk)   POINT (34.3014 31.29964)
# 84          Khan Younis_Bani Suheila  POINT (34.32628 31.34555)
# 85            Khan Younis_Khan Yunis  POINT (34.29992 31.35075)
# 86             North Gaza_Beit Hanun  POINT (34.53408 31.53146)
# 87            North Gaza_Beit Lahiya  POINT (34.50268 31.56083)
# 88                North Gaza_Jabalya   POINT (34.4822 31.53741)
# 89            North Gaza_Um Al-NASER  POINT (34.52588 31.56258)
# 90        Rafah_Al-Nnaser (Al Bayuk)  POINT (34.30578 31.28894)
# 91                       Rafah_Rafah  POINT (34.26289 31.29542)
# 92              Rafah_Shokat as Sufi   POINT (34.30233 31.2593)
#
#     This note can be read out loud  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28                             NaN
# 29                             NaN
# 30                             NaN
# 31                             NaN
# 32                             NaN
# 33                             NaN
# 34                             NaN
# 35                             NaN
# 36                             NaN
# 37                             NaN
# 38                             NaN
# 39                             NaN
# 40                             NaN
# 41                             NaN
# 42                             NaN
# 43                             NaN
# 44                             NaN
# 45                             NaN
# 46                             NaN
# 47                             NaN
# 48                             NaN
# 49                             NaN
# 50                             NaN
# 51                             NaN
# 52                             NaN
# 53                             NaN
# 54                             NaN
# 55                             NaN
# 56                             NaN
# 57                             NaN
# 58                             NaN
# 59                             NaN
# 60                             NaN
# 61                             NaN
# 62                             NaN
# 63                             NaN
# 64                             NaN
# 65                             NaN
# 66                             NaN
# 67                             NaN
# 68                             NaN
# 69                             NaN
# 70                             NaN
# 71                             NaN
# 72                             NaN
# 73                             NaN
# 74                             NaN
# 75                             NaN
# 76                             NaN
# 77                             NaN
# 78                             NaN
# 79                             NaN
# 80                             NaN
# 81                             NaN
# 82                             NaN
# 83                             NaN
# 84                             NaN
# 85                             NaN
# 86                             NaN
# 87                             NaN
# 88                             NaN
# 89                             NaN
# 90                             NaN
# 91                             NaN
# 92                             NaN
#
#     Please fill in this form if you represent a non-government organisation requesting fuel for debris removal purposes.  \
# 0                                                                                                                    NaN
# 1                                                                                                                    NaN
# 2                                                                                                                    NaN
# 3                                                                                                                    NaN
# 4                                                                                                                    NaN
# 5                                                                                                                    NaN
# 6                                                                                                                    NaN
# 7                                                                                                                    NaN
# 8                                                                                                                    NaN
# 9                                                                                                                    NaN
# 10                                                                                                                   NaN
# 11                                                                                                                   NaN
# 12                                                                                                                   NaN
# 13                                                                                                                   NaN
# 14                                                                                                                   NaN
# 15                                                                                                                   NaN
# 16                                                                                                                   NaN
# 17                                                                                                                   NaN
# 18                                                                                                                   NaN
# 19                                                                                                                   NaN
# 20                                                                                                                   NaN
# 21                                                                                                                   NaN
# 22                                                                                                                   NaN
# 23                                                                                                                   NaN
# 24                                                                                                                   NaN
# 25                                                                                                                   NaN
# 26                                                                                                                   NaN
# 27                                                                                                                   NaN
# 28                                                                                                                   NaN
# 29                                                                                                                   NaN
# 30                                                                                                                   NaN
# 31                                                                                                                   NaN
# 32                                                                                                                   NaN
# 33                                                                                                                   NaN
# 34                                                                                                                   NaN
# 35                                                                                                                   NaN
# 36                                                                                                                   NaN
# 37                                                                                                                   NaN
# 38                                                                                                                   NaN
# 39                                                                                                                   NaN
# 40                                                                                                                   NaN
# 41                                                                                                                   NaN
# 42                                                                                                                   NaN
# 43                                                                                                                   NaN
# 44                                                                                                                   NaN
# 45                                                                                                                   NaN
# 46                                                                                                                   NaN
# 47                                                                                                                   NaN
# 48                                                                                                                   NaN
# 49                                                                                                                   NaN
# 50                                                                                                                   NaN
# 51                                                                                                                   NaN
# 52                                                                                                                   NaN
# 53                                                                                                                   NaN
# 54                                                                                                                   NaN
# 55                                                                                                                   NaN
# 56                                                                                                                   NaN
# 57                                                                                                                   NaN
# 58                                                                                                                   NaN
# 59                                                                                                                   NaN
# 60                                                                                                                   NaN
# 61                                                                                                                   NaN
# 62                                                                                                                   NaN
# 63                                                                                                                   NaN
# 64                                                                                                                   NaN
# 65                                                                                                                   NaN
# 66                                                                                                                   NaN
# 67                                                                                                                   NaN
# 68                                                                                                                   NaN
# 69                                                                                                                   NaN
# 70                                                                                                                   NaN
# 71                                                                                                                   NaN
# 72                                                                                                                   NaN
# 73                                                                                                                   NaN
# 74                                                                                                                   NaN
# 75                                                                                                                   NaN
# 77  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 78  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 79  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 80  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 81  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 82  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 83  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 84  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 85  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 86  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 87  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 88  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 89  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 90  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 91  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
# 92  614871112  44c9ed81-af3b-4b46-a907-e8aa63bcb359 2025-11-25 18:25:47
#
#     _validation_status  _notes            _status  _submitted_by  \
# 0                  NaN     NaN  submitted_via_web            NaN
# 1                  NaN     NaN  submitted_via_web            NaN
# 2                  NaN     NaN  submitted_via_web            NaN
# 3                  NaN     NaN  submitted_via_web            NaN
# 4                  NaN     NaN  submitted_via_web            NaN
# 5                  NaN     NaN  submitted_via_web            NaN
# 6                  NaN     NaN  submitted_via_web            NaN
# 7                  NaN     NaN  submitted_via_web            NaN
# 8                  NaN     NaN  submitted_via_web            NaN
# 9                  NaN     NaN  submitted_via_web            NaN
# 10                 NaN     NaN  submitted_via_web            NaN
# 11                 NaN     NaN  submitted_via_web            NaN
# 12                 NaN     NaN  submitted_via_web            NaN
# 13                 NaN     NaN  submitted_via_web            NaN
# 14                 NaN     NaN  submitted_via_web            NaN
# 15                 NaN     NaN  submitted_via_web            NaN
# 16                 NaN     NaN  submitted_via_web            NaN
# 17                 NaN     NaN  submitted_via_web            NaN
# 18                 NaN     NaN  submitted_via_web            NaN
# 19                 NaN     NaN  submitted_via_web            NaN
# 20                 NaN     NaN  submitted_via_web            NaN
# 21                 NaN     NaN  submitted_via_web            NaN
# 22                 NaN     NaN  submitted_via_web            NaN
# 23                 NaN     NaN  submitted_via_web            NaN
# 24                 NaN     NaN  submitted_via_web            NaN
# 25                 NaN     NaN  submitted_via_web            NaN
# 26                 NaN     NaN  submitted_via_web            NaN
# 27                 NaN     NaN  submitted_via_web            NaN
# 28                 NaN     NaN  submitted_via_web            NaN
# 29                 NaN     NaN  submitted_via_web            NaN
# 30                 NaN     NaN  submitted_via_web            NaN
# 31                 NaN     NaN  submitted_via_web            NaN
# 32                 NaN     NaN  submitted_via_web            NaN
# 33                 NaN     NaN  submitted_via_web            NaN
# 34                 NaN     NaN  submitted_via_web            NaN
# 35                 NaN     NaN  submitted_via_web            NaN
# 36                 NaN     NaN  submitted_via_web            NaN
# 37                 NaN     NaN  submitted_via_web            NaN
# 38                 NaN     NaN  submitted_via_web            NaN
# 39                 NaN     NaN  submitted_via_web            NaN
# 40                 NaN     NaN  submitted_via_web            NaN
# 41                 NaN     NaN  submitted_via_web            NaN
# 42                 NaN     NaN  submitted_via_web            NaN
# 43                 NaN     NaN  submitted_via_web            NaN
# 44                 NaN     NaN  submitted_via_web            NaN
# 45                 NaN     NaN  submitted_via_web            NaN
# 46                 NaN     NaN  submitted_via_web            NaN
# 47                 NaN     NaN  submitted_via_web            NaN
# 48                 NaN     NaN  submitted_via_web            NaN
# 49                 NaN     NaN  submitted_via_web            NaN
# 50                 NaN     NaN  submitted_via_web            NaN
# 51                 NaN     NaN  submitted_via_web            NaN
# 52                 NaN     NaN  submitted_via_web            NaN
# 53                 NaN     NaN  submitted_via_web            NaN
# 54                 NaN     NaN  submitted_via_web            NaN
# 55                 NaN     NaN  submitted_via_web            NaN
# 56                 NaN     NaN  submitted_via_web            NaN
# 57                 NaN     NaN  submitted_via_web            NaN
# 58                 NaN     NaN  submitted_via_web            NaN
# 59                 NaN     NaN  submitted_via_web            NaN
# 60                 NaN     NaN  submitted_via_web            NaN
# 61                 NaN     NaN  submitted_via_web            NaN
# 62                 NaN     NaN  submitted_via_web            NaN
# 63                 NaN     NaN  submitted_via_web            NaN
# 64                 NaN     NaN  submitted_via_web            NaN
# 65                 NaN     NaN  submitted_via_web            NaN
# 66                 NaN     NaN  submitted_via_web            NaN
# 67                 NaN     NaN  submitted_via_web            NaN
# 68                 NaN     NaN  submitted_via_web            NaN
# 69                 NaN     NaN  submitted_via_web            NaN
# 70                 NaN     NaN  submitted_via_web            NaN
# 71                 NaN     NaN  submitted_via_web            NaN
# 72                 NaN     NaN  submitted_via_web            NaN
# 73                 NaN     NaN  submitted_via_web            NaN
# 74                 NaN     NaN  submitted_via_web            NaN
# 75                 NaN     NaN  submitted_via_web            NaN
# 76                 NaN     NaN  submitted_via_web            NaN
# 77                 NaN     NaN  submitted_via_web            NaN
# 78                 NaN     NaN  submitted_via_web            NaN
# 79                 NaN     NaN  submitted_via_web            NaN
# 80                 NaN     NaN  submitted_via_web            NaN
# 81                 NaN     NaN  submitted_via_web            NaN
# 82                 NaN     NaN  submitted_via_web            NaN
# 83                 NaN     NaN  submitted_via_web            NaN
# 84                 NaN     NaN  submitted_via_web            NaN
# 85                 NaN     NaN  submitted_via_web            NaN
# 86                 NaN     NaN  submitted_via_web            NaN
# 87                 NaN     NaN  submitted_via_web            NaN
# 88                 NaN     NaN  submitted_via_web            NaN
# 89                 NaN     NaN  submitted_via_web            NaN
# 90                 NaN     NaN  submitted_via_web            NaN
# 91                 NaN     NaN  submitted_via_web            NaN
# 92                 NaN     NaN  submitted_via_web            NaN
#
#                __version__  _tags  _index
# 0   vrUo2zbbGfNkhDf8V63RcD    NaN       1
# 1   vrUo2zbbGfNkhDf8V63RcD    NaN       2
# 2   vn3LwfJj9CHwtUAVPUauxa    NaN       3
# 3   vn3LwfJj9CHwtUAVPUauxa    NaN       3
# 4   vaY28MWx3PuyJsMiDtRXix    NaN       4
# 5   vaY28MWx3PuyJsMiDtRXix    NaN       4
# 6   vaY28MWx3PuyJsMiDtRXix    NaN       4
# 7   v9j7GrtCx8DU3Tgt3p5HED    NaN       5
# 8   v9j7GrtCx8DU3Tgt3p5HED    NaN       5
# 9   v9j7GrtCx8DU3Tgt3p5HED    NaN       5
# 10  v9j7GrtCx8DU3Tgt3p5HED    NaN       5
# 11  v9j7GrtCx8DU3Tgt3p5HED    NaN       6
# 12  v9j7GrtCx8DU3Tgt3p5HED    NaN       6
# 13  v9j7GrtCx8DU3Tgt3p5HED    NaN       6
# 14  v9j7GrtCx8DU3Tgt3p5HED    NaN       6
# 15  v9j7GrtCx8DU3Tgt3p5HED    NaN       6
# 16  v9j7GrtCx8DU3Tgt3p5HED    NaN       6
# 17  v9j7GrtCx8DU3Tgt3p5HED    NaN       6
# 18  v9j7GrtCx8DU3Tgt3p5HED    NaN       6
# 19  v9j7GrtCx8DU3Tgt3p5HED    NaN       6
# 20  v9j7GrtCx8DU3Tgt3p5HED    NaN       6
# 21  vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 22  vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 23  vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 24  vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 25  vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 26  vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 27  vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 28  vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 29  vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 30  vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 31  vn3LwfJj9CHwtUAVPUauxa    NaN       7
# 32  v9j7GrtCx8DU3Tgt3p5HED    NaN       8
# 33  v9j7GrtCx8DU3Tgt3p5HED    NaN       8
# 34  v9j7GrtCx8DU3Tgt3p5HED    NaN       8
# 35  v9j7GrtCx8DU3Tgt3p5HED    NaN       8
# 36  v9j7GrtCx8DU3Tgt3p5HED    NaN       9
# 37  v9j7GrtCx8DU3Tgt3p5HED    NaN      10
# 38  v9j7GrtCx8DU3Tgt3p5HED    NaN      10
# 39  vvU2Bg4uP9fRRZLbJyMvKn    NaN      11
# 40  vvU2Bg4uP9fRRZLbJyMvKn    NaN      11
# 41  vvU2Bg4uP9fRRZLbJyMvKn    NaN      11
# 42  vvU2Bg4uP9fRRZLbJyMvKn    NaN      11
# 43  vFMPfevk3YYzmYrGVjsriB    NaN      12
# 44  vFMPfevk3YYzmYrGVjsriB    NaN      12
# 45  vFMPfevk3YYzmYrGVjsriB    NaN      12
# 46  vFMPfevk3YYzmYrGVjsriB    NaN      13
    df.columns = df.columns.str.replace(r"[.]", "_", regex=True)
    df.columns = df.columns.str.replace(r"[?]", "_", regex=True)
    df.columns = df.columns.str.replace(r"[']", "", regex=True)
    df.columns = df.columns.str.replace(r"[(]", "", regex=True)
    df.columns = df.columns.str.replace(r"[)]", "", regex=True)
    df.columns = df.columns.str.replace(r"[[]", "", regex=True)
    df.columns = df.columns.str.replace(r"[]]", "", regex=True)
    df.columns = df.columns.str.replace(r"[%]", "_", regex=True)
    df.columns = map(str.lower, df.columns)
    
    # Remove leading underscores
    df = df.rename(columns={
        '_id':'f_id',
        '_uuid':'f_uuid',
    })
    df.columns = df.columns.str.lstrip('_')
    
    #Truncate and ensure uniqueness
    seen = {}
    final_cols = []
    max_length = 31
    for col in df.columns:
        base = col[:max_length]
        new_col = base
        i = 1
        while new_col in seen:
            suffix = f"_{i}"
            trim_len = max_length - len(suffix)
            new_col = base[:trim_len] + suffix
            i += 1
        seen[new_col] = True
        final_cols.append(new_col)
    
    # Step 4: Apply to DataFrame
    df.columns = final_cols
    return df

gdf_exploded = makeArcGISfriendly(gdf_filtrado)

# %%
def simplifyGeometries(df):
    df['geometry'] = df['geometry'].centroid
    return df
    
gdf_exploded = simplifyGeometries(gdf_exploded)

seen = set()
unique_flags = []

for _, row in gdf_exploded.iterrows():
    if row['f_id'] in seen:
        unique_flags.append('')
    else:
        unique_flags.append('yes')
        seen.add(row['f_id'])

gdf_exploded['unique_'] = unique_flags

# %%
#### UPDATE DATA IN ARCGIS

#Connect to the ArcGIS Enterprise portal

AGOL_USERNAME = 'h.partow'
AGOL_PASSWORD = 'R&Runit2024'
gis = GIS('https://wesrmapportal.unep.org/portal/', AGOL_USERNAME, AGOL_PASSWORD)

# Access the feature-layer through its URL
file = "https://wesrmapportal.unep.org/arcgis/rest/services/Hosted/DWG_Gaza_Fuel_Requests_Responses/FeatureServer"

# Access the feature-layer through its URL
fuel_file = 'DWG_Gaza_Fuel_RequestsResponses'

# %%
def searchArcgis(keyword):
    if not isinstance(keyword, str):
        raise TypeError(f"Esperado 'str' em 'keyword', recebido {type(keyword)} → {keyword}")
    results = gis.content.search(f'title:\"{keyword}\"', item_type="Feature Layer")
    if not results:
        print("Nenhum resultado encontrado para", keyword)
        return None
    results_sorted = sorted(results, key=lambda x: x.modified, reverse=True)
    return results_sorted[0]

search_fuel = searchArcgis(fuel_file)

# %%
def updateFeature(search_results, gdf):

    item = gis.content.get(search_results.id)

    flc = FeatureLayerCollection.fromitem(item)
    layer = flc.layers[0]  # Assuming you're working with the first layer


    # Step 1: Truncate features
    truncate_result = layer.manager.truncate()
    print("Truncate result:", truncate_result)

    # Keep only matching columns
    expected_fields = [f["name"] for f in layer.properties.fields if f["name"] != "fid"]
    gdf = gdf[[col for col in gdf.columns if col in expected_fields or col == "geometry"]]

    gdf = gdf.to_crs(epsg=4326)

    sedf = GeoAccessor.from_geodataframe(gdf)

    fs = FeatureSet.from_dataframe(sedf)

    result = layer.edit_features(adds=fs.features)
    print("Result:", result)
    return(result)

updateFeature(search_fuel, gdf_exploded)
