# %%
# import requirements 
import requests
import re
import pandas as pd
import geopandas as gpd
from arcgis.gis import GIS
import os
import numpy as np
from arcgis.features import FeatureLayerCollection
from arcgis.features import FeatureSet, GeoAccessor
from arcgis.geometry import Geometry

# %%
#Import external files
governorate_municipality = gpd.read_file("UNEP_Gaza_Governorate_Municipality_Singleparts_POINTS.gpkg")
governorate_municipality = governorate_municipality.to_crs(epsg=4326)
governorate_municipality.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#Read this to know more about how Kobo handles synchronous exports and where to find the right url
#https://support.kobotoolbox.org/synchronous_exports.html

#### FETCH KOBO DATA

# Authentication credentials
KOBO_USERNAME = "guilherme_iablonovski"
KOBO_PASSWORD = "k0b0Senha"
export_token = "f72722c6ffe97db14144325853528a4b7a1c059b"

#Fuel Request API endpoint
kobo_api_url = "https://kf.kobotoolbox.org/api/v2/assets/aYyrjnacEdnBdZnXaxMcG5/export-settings/eskV2HM9SKSUw6pB93aZqWK"

# %%
def getKoboForm(url):
    # Create a session with authentication
    session = requests.Session()
    session.auth = (KOBO_USERNAME, KOBO_PASSWORD)

    # Construct the export URL
    kobo_export_url = f"{url}/data.xlsx"#?format=csv&token={export_token}"

    # Fetch data using the authenticated session
    response = session.get(kobo_export_url)

    # Check if the request was successful
    if response.status_code == 200:
        # Load data into a pandas DataFrame
        kobo_data = pd.read_excel(response.content)
        kobo_data.head()
        return kobo_data
    else:
        print("Error:", response.status_code)
        
kobo_data = getKoboForm(kobo_api_url)
# Out:
# C:\Users\joses\AppData\Local\Temp\ipykernel_6384\399000899.py:15: FutureWarning: Passing bytes to 'read_excel' is deprecated and will be removed in a future version. To read from a byte string, wrap it in a `BytesIO` object.
#   kobo_data = pd.read_excel(response.content)

# %%
kobo_data
# Out:
#     This note can be read out loud  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
#
#     Please fill in this form if you represent a non-government organisation requesting fuel for debris removal purposes.  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#    Implementing agency                 Please specify  Contact person name  \
# 0                  NaN                            NaN                  NaN
# 1                  NaN                            NaN                  NaN
# 2                  NaN                            NaN                  NaN
# 3                  NaN                            NaN                  NaN
# 4                  NaN                            NaN                  NaN
# 5                  NaN                            NaN                  NaN
# 6                  NaN                            NaN                  NaN
# 7                  NaN                            NaN                  NaN
# 8                  NaN                            NaN                  NaN
# 9                  NaN                            NaN                  NaN
# 10                UNDP                            NaN  Mohammed Abu Mezyed
# 11               Other                          AIOCP        Ahmed alghuff
# 12               Other        AIOCP-gaza municipality        Ahmed alghuff
# 13               Other                  AIOCP-jabalia        Ahmed alghuff
# 14                UNDP                            NaN  Mohammed Abu Mezyed
# 15               Other  AIOCP-khanyounes municipality        Ahmed alghuff
# 16               Other             Egyptian Committee          Ahmed Zakri
# 17               AIOCP                            NaN       ahmed al ghuff
# 18               AIOCP                            NaN       ahmed al ghuff
# 19               AIOCP                            NaN       ahmed al ghuff
# 20               AIOCP                            NaN       ahmed al ghuff
# 21               AIOCP                            NaN       ahmed al ghuff
# 22                 IOM                            NaN                 test
#
#                      Contact person phone number Contact person email address  \
# 0                                            NaN                          NaN
# 1                                            NaN                          NaN
# 2                                            NaN                          NaN
# 3                                            NaN                          NaN
# 4                                            NaN                          NaN
# 5                                            NaN                          NaN
# 6                                            NaN                          NaN
# 7                                            NaN                          NaN
# 8                                            NaN                          NaN
# 9                                            NaN                          NaN
# 10                                    0599800169     Mohammad.Mezyad@undp.org
# 11                                    0598120400       Ahmedghuff@palimar.org
# 12                                    0598120400       Ahmedghuff@palimar.org
# 13                                    0598120400     Ahmedalghuff@palimar.org
# 14  Chief Technical Specialist-Debris Management     mohammad.mezyad@undp.org
# 15                                    0598120400       Ahmedghuff@palimar.org
# 16                                 +970595596020         xahmad1105@gmail.com
# 17                                    0598120400       ahmedghuff@palimar.org
# 18                                    0598120400       ahmedghuff@palimar.org
# 19                                    0598120400       ahmedghuff@palimar.org
# 20                                    0598120400       ahmedghuff@palimar.org
# 21                                    0598120400       ahmedghuff@palimar.org
# 22                                          test                         test
#
#    Do you have a MoU with UNOPS? Location of planned intervention(s)  \
# 0                            NaN                       Deir Al-Balah
# 1                            NaN                         Khan Younis
# 2                            NaN           Deir Al-Balah Khan Younis
# 3                            NaN                     Gaza North Gaza
# 4                            NaN         Gaza Khan Younis North Gaza
# 5                            NaN      Deir Al-Balah Gaza Khan Younis
# 6                            NaN      Deir Al-Balah Gaza Khan Younis
# 7                            NaN         Gaza Khan Younis North Gaza
# 8                            NaN                         Khan Younis
# 9                            NaN                                Gaza
# 10                           Yes      Deir Al-Balah Gaza Khan Younis
# 11                           Yes         Gaza Khan Younis North Gaza
# 12                           Yes                                Gaza
# 13                           Yes                          North Gaza
# 14                           Yes      Deir Al-Balah Gaza Khan Younis
# 15                           Yes                         Khan Younis
# 16                            No                                 NaN
# 17                           Yes         Gaza Khan Younis North Gaza
# 18                           Yes                                Gaza
# 19                           Yes                          North Gaza
# 20                           Yes                         Khan Younis
# 21                           Yes                          North Gaza
# 22                           Yes                         Khan Younis
#
#       Please specify the municipality (Deir Al-Balah)  ...        _id  \
# 0                                      Deir al Balah.  ...  509204309
# 1                                                 NaN  ...  509613833
# 2                                      Deir al Balah.  ...  554713303
# 3                                                 NaN  ...  580205978
# 4                                                 NaN  ...  584623219
# 5   Al Bureij. Al Maghazi. Al Musaddar. An Nuseira...  ...  584657848
# 6   Al Bureij. Al Maghazi. Al Musaddar. Al Qarara....  ...  584680179
# 7                                                 NaN  ...  588789860
# 8                                                 NaN  ...  588791570
# 9                                                 NaN  ...  588792542
# 10                                     Deir al Balah.  ...  588865776
# 11                                                NaN  ...  593842372
# 12                                                NaN  ...  593843798
# 13                                                NaN  ...  593845053
# 14          Az Zawayda. Deir al Balah. Wadi as Salqa.  ...  594126958
# 15                                                NaN  ...  596239852
# 16                                                NaN  ...  600078169
# 17                                                NaN  ...  603900307
# 18                                                NaN  ...  603901745
# 19                                                NaN  ...  603902413
# 20                                                NaN  ...  603903320
# 21                                                NaN  ...  603903975
# 22                                                NaN  ...  614860061
#
#                                    _uuid    _submission_time  \
# 0   5e99250e-4ebf-401b-b913-344d9b453967 2025-07-02 13:43:58
# 1   b3021b66-fc42-441a-bd1f-a8704aadc8d1 2025-07-03 06:33:49
# 2   c9d9d7dc-3feb-49fc-9a92-67af1172e501 2025-09-09 07:08:43
# 3   98abb206-0760-4eff-add7-9b2f3b662bd1 2025-10-11 15:38:18
# 4   110bdf70-e4a5-44ee-9911-91a1bb328b19 2025-10-17 10:32:21
# 5   249825ad-e692-4bf5-a76a-5d424acf7e20 2025-10-17 11:17:45
# 6   7f67fb6a-3ccd-4d7d-841f-e35fdcc5be16 2025-10-17 11:46:53
# 7   d747f52f-d85b-4247-aba2-2c6ad214b784 2025-10-23 05:15:21
# 8   920d79ec-c687-4567-9c50-8c43567cbe38 2025-10-23 05:19:36
# 9   607a0e99-6337-43fa-b563-ceb09f1ec054 2025-10-23 05:21:27
# 10  84a76928-f6b4-4d23-a816-bb9908b8f4c8 2025-10-23 07:22:19
# 11  fa985f61-df30-4240-800c-9d2dffa2f46b 2025-10-29 18:02:01
# 12  b1bbcda9-7633-4f13-80f9-ef806b3f574c 2025-10-29 18:04:36
# 13  e1ab52fc-9700-4082-acdf-228da1aa3f85 2025-10-29 18:06:37
# 14  fc69fc56-f83a-42d7-9286-e581112826ad 2025-10-30 06:38:03
# 15  8b707bce-7bab-45b1-8a0b-e8a865335851 2025-11-02 06:10:20
# 16  540230b2-01a8-4ff1-bc14-21d934c3c987 2025-11-06 19:04:42
# 17  df479171-bc9a-4ad1-8459-0f602f297248 2025-11-12 09:26:49
# 18  2c46726e-ccb1-4379-9d0f-020e165fcac6 2025-11-12 09:28:11
# 19  b0597b75-1f4e-4387-9c65-439effc5c8ac 2025-11-12 09:28:54
# 20  3049b76a-0f10-446d-bc26-043f5f4b6024 2025-11-12 09:30:01
# 21  6b638b18-0492-4e0f-a7e5-a56fc2f34295 2025-11-12 09:30:51
# 22  0fabf608-187e-40e7-bebd-b1cd906fafd0 2025-11-25 18:08:06
#
#     _validation_status _notes            _status _submitted_by  \
# 0                  NaN    NaN  submitted_via_web           NaN
# 1                  NaN    NaN  submitted_via_web           NaN
# 2                  NaN    NaN  submitted_via_web           NaN
# 3                  NaN    NaN  submitted_via_web           NaN
# 4                  NaN    NaN  submitted_via_web           NaN
# 5                  NaN    NaN  submitted_via_web           NaN
# 6                  NaN    NaN  submitted_via_web           NaN
# 7                  NaN    NaN  submitted_via_web           NaN
# 8                  NaN    NaN  submitted_via_web           NaN
# 9                  NaN    NaN  submitted_via_web           NaN
# 10                 NaN    NaN  submitted_via_web           NaN
# 11                 NaN    NaN  submitted_via_web           NaN
# 12                 NaN    NaN  submitted_via_web           NaN
# 13                 NaN    NaN  submitted_via_web           NaN
# 14                 NaN    NaN  submitted_via_web           NaN
# 15                 NaN    NaN  submitted_via_web           NaN
# 16                 NaN    NaN  submitted_via_web           NaN
# 17                 NaN    NaN  submitted_via_web           NaN
# 18                 NaN    NaN  submitted_via_web           NaN
# 19                 NaN    NaN  submitted_via_web           NaN
# 20                 NaN    NaN  submitted_via_web           NaN
# 21                 NaN    NaN  submitted_via_web           NaN
# 22                 NaN    NaN  submitted_via_web           NaN
#
#                __version__  _tags _index
# 0   vrUo2zbbGfNkhDf8V63RcD    NaN      1
# 1   vrUo2zbbGfNkhDf8V63RcD    NaN      2
# 2   vn3LwfJj9CHwtUAVPUauxa    NaN      3
# 3   vaY28MWx3PuyJsMiDtRXix    NaN      4
# 4   v9j7GrtCx8DU3Tgt3p5HED    NaN      5
# 5   v9j7GrtCx8DU3Tgt3p5HED    NaN      6
# 6   vn3LwfJj9CHwtUAVPUauxa    NaN      7
# 7   v9j7GrtCx8DU3Tgt3p5HED    NaN      8
# 8   v9j7GrtCx8DU3Tgt3p5HED    NaN      9
# 9   v9j7GrtCx8DU3Tgt3p5HED    NaN     10
# 10  vvU2Bg4uP9fRRZLbJyMvKn    NaN     11
# 11  vFMPfevk3YYzmYrGVjsriB    NaN     12
# 12  vFMPfevk3YYzmYrGVjsriB    NaN     13
# 13  vFMPfevk3YYzmYrGVjsriB    NaN     14
# 14  vvTrAibjDz3pTeScPNavsX    NaN     15
# 15  vFMPfevk3YYzmYrGVjsriB    NaN     16
# 16  vRN8bzjcij4TyUXBx5vhfN    NaN     17
# 17  vRN8bzjcij4TyUXBx5vhfN    NaN     18
# 18  vRN8bzjcij4TyUXBx5vhfN    NaN     19
# 19  vRN8bzjcij4TyUXBx5vhfN    NaN     20
# 20  vRN8bzjcij4TyUXBx5vhfN    NaN     21
# 21  vRN8bzjcij4TyUXBx5vhfN    NaN     22
# 22  vRN8bzjcij4TyUXBx5vhfN    NaN     23
#
# [23 rows x 35 columns]

# %%
# Identifica as colunas que começam com "Please specify the municipality"
cols = [c for c in kobo_data.columns if c.startswith("Please specify the municipality")]

# Cria uma lista para armazenar os registros explodidos
records = []

# Itera sobre cada linha e coluna dessas
for _, row in kobo_data.iterrows():
    base_data = {col: row[col] for col in kobo_data.columns if col not in cols}  # mantém outras colunas

    for col in cols:
        val = row[col]
        if pd.isna(val):
            continue

        # Extrai o nome entre parênteses
        match = re.search(r'\((.*?)\)', col)
        governo = match.group(1).strip() if match else ''

        # Divide as respostas usando ". " como separador
        municipios = re.split(r'(?<=\.)\s+', str(val).strip())

        # Limpa e forma a nova lista com "Governo_Município"
        for m in municipios:
            m = m.strip().rstrip('.')
            if m:
                new_row = base_data.copy()
                new_row['Gov_Mun'] = f"{governo}_{m}"
                records.append(new_row)

# Cria o novo DataFrame com as linhas expandidas
kobo_data_exploded = pd.DataFrame(records).reset_index(drop=True)

# %%
kobo_data_exploded
# Out:
#     This note can be read out loud  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 63                             NaN
# 64                             NaN
# 65                             NaN
# 66                             NaN
# 67                             NaN
#
#     Please fill in this form if you represent a non-government organisation requesting fuel for debris removal purposes.  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
#
#    Implementing agency Please specify Contact person name  \
# 0                  NaN            NaN                 NaN
# 1                  NaN            NaN                 NaN
# 2                  NaN            NaN                 NaN
# 3                  NaN            NaN                 NaN
# 4                  NaN            NaN                 NaN
# ..                 ...            ...                 ...
# 63               AIOCP            NaN      ahmed al ghuff
# 64               AIOCP            NaN      ahmed al ghuff
# 65               AIOCP            NaN      ahmed al ghuff
# 66               AIOCP            NaN      ahmed al ghuff
# 67                 IOM            NaN                test
#
#    Contact person phone number Contact person email address  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# ..                         ...                          ...
# 63                  0598120400       ahmedghuff@palimar.org
# 64                  0598120400       ahmedghuff@palimar.org
# 65                  0598120400       ahmedghuff@palimar.org
# 66                  0598120400       ahmedghuff@palimar.org
# 67                        test                         test
#
#    Do you have a MoU with UNOPS? Location of planned intervention(s)  \
# 0                            NaN                       Deir Al-Balah
# 1                            NaN                         Khan Younis
# 2                            NaN           Deir Al-Balah Khan Younis
# 3                            NaN           Deir Al-Balah Khan Younis
# 4                            NaN                     Gaza North Gaza
# ..                           ...                                 ...
# 63                           Yes                                Gaza
# 64                           Yes                          North Gaza
# 65                           Yes                         Khan Younis
# 66                           Yes                          North Gaza
# 67                           Yes                         Khan Younis
#
#    Type of site  ...                                 _uuid  \
# 0          Road  ...  5e99250e-4ebf-401b-b913-344d9b453967
# 1          Road  ...  b3021b66-fc42-441a-bd1f-a8704aadc8d1
# 2          Road  ...  c9d9d7dc-3feb-49fc-9a92-67af1172e501
# 3          Road  ...  c9d9d7dc-3feb-49fc-9a92-67af1172e501
# 4          Road  ...  98abb206-0760-4eff-add7-9b2f3b662bd1
# ..          ...  ...                                   ...
# 63         Road  ...  2c46726e-ccb1-4379-9d0f-020e165fcac6
# 64         Road  ...  b0597b75-1f4e-4387-9c65-439effc5c8ac
# 65         Road  ...  3049b76a-0f10-446d-bc26-043f5f4b6024
# 66         Road  ...  6b638b18-0492-4e0f-a7e5-a56fc2f34295
# 67         Road  ...  0fabf608-187e-40e7-bebd-b1cd906fafd0
#
#       _submission_time _validation_status  _notes            _status  \
# 0  2025-07-02 13:43:58                NaN     NaN  submitted_via_web
# 1  2025-07-03 06:33:49                NaN     NaN  submitted_via_web
# 2  2025-09-09 07:08:43                NaN     NaN  submitted_via_web
# 3  2025-09-09 07:08:43                NaN     NaN  submitted_via_web
# 4  2025-10-11 15:38:18                NaN     NaN  submitted_via_web
# ..                 ...                ...     ...                ...
# 63 2025-11-12 09:28:11                NaN     NaN  submitted_via_web
# 64 2025-11-12 09:28:54                NaN     NaN  submitted_via_web
# 65 2025-11-12 09:30:01                NaN     NaN  submitted_via_web
# 66 2025-11-12 09:30:51                NaN     NaN  submitted_via_web
# 67 2025-11-25 18:08:06                NaN     NaN  submitted_via_web
#
#     _submitted_by             __version__ _tags  _index  \
# 0             NaN  vrUo2zbbGfNkhDf8V63RcD   NaN       1
# 1             NaN  vrUo2zbbGfNkhDf8V63RcD   NaN       2
# 2             NaN  vn3LwfJj9CHwtUAVPUauxa   NaN       3
# 3             NaN  vn3LwfJj9CHwtUAVPUauxa   NaN       3
# 4             NaN  vaY28MWx3PuyJsMiDtRXix   NaN       4
# ..            ...                     ...   ...     ...
# 63            NaN  vRN8bzjcij4TyUXBx5vhfN   NaN      19
# 64            NaN  vRN8bzjcij4TyUXBx5vhfN   NaN      20
# 65            NaN  vRN8bzjcij4TyUXBx5vhfN   NaN      21
# 66            NaN  vRN8bzjcij4TyUXBx5vhfN   NaN      22
# 67            NaN  vRN8bzjcij4TyUXBx5vhfN   NaN      23
#
#                          Gov_Mun
# 0    Deir Al-Balah_Deir al Balah
# 1         Khan Younis_Khan Yunis
# 2    Deir Al-Balah_Deir al Balah
# 3         Khan Younis_Khan Yunis
# 4                      Gaza_Gaza
# ..                           ...
# 63                     Gaza_Gaza
# 64            North Gaza_Jabalya
# 65        Khan Younis_Khan Yunis
# 66        North Gaza_Beit Lahiya
# 67  Khan Younis_Abasan al Kabira
#
# [68 rows x 31 columns]

# %%
#### INITIAL CLEANING

#Standardize data for municipalities without neighborhoods

def standardize(df):

    kobo_data_0 = df.replace(0, None)  
    return kobo_data_0

kobo_data_exploded = standardize(kobo_data_exploded)

# Faz o join com o gdf, mantendo todos os municípios originais

gdf_filtrado = governorate_municipality.merge(kobo_data_exploded, on='Gov_Mun', how='right')

# %%
gdf_filtrado.plot()
# Out:
# <Axes: >

# %%
#Handle columns so they are not modified by arcgis when uploaded
def makeArcGISfriendly(df):
    df.columns = df.columns.str.replace(r"[ ]", "_", regex=True)
    df.columns = df.columns.str.replace(r"[.]", "_", regex=True)
    df.columns = df.columns.str.replace(r"[?]", "_", regex=True)
    df.columns = df.columns.str.replace(r"[']", "", regex=True)
    df.columns = df.columns.str.replace(r"[(]", "", regex=True)
    df.columns = df.columns.str.replace(r"[)]", "", regex=True)
    df.columns = df.columns.str.replace(r"[[]", "", regex=True)
    df.columns = df.columns.str.replace(r"[]]", "", regex=True)
    df.columns = df.columns.str.replace(r"[%]", "_", regex=True)
    df.columns = map(str.lower, df.columns)
    
    # Remove leading underscores
    df = df.rename(columns={
        '_id':'f_id',
        '_uuid':'f_uuid',
    })
    df.columns = df.columns.str.lstrip('_')
    
    #Truncate and ensure uniqueness
    seen = {}
    final_cols = []
    max_length = 31
    for col in df.columns:
        base = col[:max_length]
        new_col = base
        i = 1
        while new_col in seen:
            suffix = f"_{i}"
            trim_len = max_length - len(suffix)
            new_col = base[:trim_len] + suffix
            i += 1
        seen[new_col] = True
        final_cols.append(new_col)
    
    # Step 4: Apply to DataFrame
    df.columns = final_cols
    return df

gdf_exploded = makeArcGISfriendly(gdf_filtrado)
# Out:
# c:\Users\joses\anaconda3\Lib\site-packages\pandas\core\strings\object_array.py:172: FutureWarning: Possible nested set at position 1
#   pat = re.compile(pat, flags=flags)

# %%
def simplifyGeometries(df):
    df['geometry'] = df['geometry'].centroid
    return df
    
gdf_exploded = simplifyGeometries(gdf_exploded)

seen = set()
unique_flags = []

for _, row in gdf_exploded.iterrows():
    if row['f_id'] in seen:
        unique_flags.append('')
    else:
        unique_flags.append('yes')
        seen.add(row['f_id'])

gdf_exploded['unique_'] = unique_flags
# Out:
# C:\Users\joses\AppData\Local\Temp\ipykernel_6384\3564463087.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   df['geometry'] = df['geometry'].centroid

# %%
#### UPDATE DATA IN ARCGIS

#Connect to the ArcGIS Enterprise portal

AGOL_USERNAME = 'h.partow'
AGOL_PASSWORD = 'R&Runit2024'
gis = GIS('https://wesrmapportal.unep.org/portal/', AGOL_USERNAME, AGOL_PASSWORD)

# Access the feature-layer through its URL
file = "https://wesrmapportal.unep.org/arcgis/rest/services/Hosted/DWG_Gaza_Fuel_Requests_Responses/FeatureServer"

# Access the feature-layer through its URL
fuel_file = 'DWG_Gaza_Fuel_RequestsResponses'

# %%
def searchArcgis(keyword):
    if not isinstance(keyword, str):
        raise TypeError(f"Esperado 'str' em 'keyword', recebido {type(keyword)} → {keyword}")
    results = gis.content.search(f'title:\"{keyword}\"', item_type="Feature Layer")
    if not results:
        print("Nenhum resultado encontrado para", keyword)
        return None
    results_sorted = sorted(results, key=lambda x: x.modified, reverse=True)
    return results_sorted[0]

search_fuel = searchArcgis(fuel_file)

# %%
def updateFeature(search_results, gdf):

    item = gis.content.get(search_results.id)

    flc = FeatureLayerCollection.fromitem(item)
    layer = flc.layers[0]  # Assuming you're working with the first layer


    # Step 1: Truncate features
    truncate_result = layer.manager.truncate()
    print("Truncate result:", truncate_result)

    # Keep only matching columns
    expected_fields = [f["name"] for f in layer.properties.fields if f["name"] != "fid"]
    gdf = gdf[[col for col in gdf.columns if col in expected_fields or col == "geometry"]]

    gdf = gdf.to_crs(epsg=4326)

    sedf = GeoAccessor.from_geodataframe(gdf)

    fs = FeatureSet.from_dataframe(sedf)

    result = layer.edit_features(adds=fs.features)
    print("Result:", result)
    return(result)

updateFeature(search_fuel, gdf_exploded)
# Out:
# Truncate result: {'success': True}
# Result: {'addResults': [{'success': True, 'objectId': 1}, {'success': True, 'objectId': 2}, {'success': True, 'objectId': 3}, {'success': True, 'objectId': 4}, {'success': True, 'objectId': 5}, {'success': True, 'objectId': 6}, {'success': True, 'objectId': 7}, {'success': True, 'objectId': 8}, {'success': True, 'objectId': 9}, {'success': True, 'objectId': 10}, {'success': True, 'objectId': 11}, {'success': True, 'objectId': 12}, {'success': True, 'objectId': 13}, {'success': True, 'objectId': 14}, {'success': True, 'objectId': 15}, {'success': True, 'objectId': 16}, {'success': True, 'objectId': 17}, {'success': True, 'objectId': 18}, {'success': True, 'objectId': 19}, {'success': True, 'objectId': 20}, {'success': True, 'objectId': 21}, {'success': True, 'objectId': 22}, {'success': True, 'objectId': 23}, {'success': True, 'objectId': 24}, {'success': True, 'objectId': 25}, {'success': True, 'objectId': 26}, {'success': True, 'objectId': 27}, {'success': True, 'objectId': 28}, {'success': True, 'objectId': 29}, {'success': True, 'objectId': 30}, {'success': True, 'objectId': 31}, {'success': True, 'objectId': 32}, {'success': True, 'objectId': 33}, {'success': True, 'objectId': 34}, {'success': True, 'objectId': 35}, {'success': True, 'objectId': 36}, {'success': True, 'objectId': 37}, {'success': True, 'objectId': 38}, {'success': True, 'objectId': 39}, {'success': True, 'objectId': 40}, {'success': True, 'objectId': 41}, {'success': True, 'objectId': 42}, {'success': True, 'objectId': 43}, {'success': True, 'objectId': 44}, {'success': True, 'objectId': 45}, {'success': True, 'objectId': 46}, {'success': True, 'objectId': 47}, {'success': True, 'objectId': 48}, {'success': True, 'objectId': 49}, {'success': True, 'objectId': 50}, {'success': True, 'objectId': 51}, {'success': True, 'objectId': 52}, {'success': True, 'objectId': 53}, {'success': True, 'objectId': 54}, {'success': True, 'objectId': 55}, {'success': True, 'objectId': 56}, {'success': True, 'objectId': 57}, {'success': True, 'objectId': 58}, {'success': True, 'objectId': 59}, {'success': True, 'objectId': 60}, {'success': True, 'objectId': 61}, {'success': True, 'objectId': 62}, {'success': True, 'objectId': 63}, {'success': True, 'objectId': 64}, {'success': True, 'objectId': 65}, {'success': True, 'objectId': 66}, {'success': True, 'objectId': 67}, {'success': True, 'objectId': 68}], 'updateResults': [], 'deleteResults': []}
# {'addResults': [{'success': True, 'objectId': 1},
#   {'success': True, 'objectId': 2},
#   {'success': True, 'objectId': 3},
#   {'success': True, 'objectId': 4},
#   {'success': True, 'objectId': 5},
#   {'success': True, 'objectId': 6},
#   {'success': True, 'objectId': 7},
#   {'success': True, 'objectId': 8},
#   {'success': True, 'objectId': 9},
#   {'success': True, 'objectId': 10},
#   {'success': True, 'objectId': 11},
#   {'success': True, 'objectId': 12},
#   {'success': True, 'objectId': 13},
#   {'success': True, 'objectId': 14},
#   {'success': True, 'objectId': 15},
#   {'success': True, 'objectId': 16},
#   {'success': True, 'objectId': 17},
#   {'success': True, 'objectId': 18},
#   {'success': True, 'objectId': 19},
#   {'success': True, 'objectId': 20},
#   {'success': True, 'objectId': 21},
#   {'success': True, 'objectId': 22},
#   {'success': True, 'objectId': 23},
#   {'success': True, 'objectId': 24},
#   {'success': True, 'objectId': 25},
#   {'success': True, 'objectId': 26},
#   {'success': True, 'objectId': 27},
#   {'success': True, 'objectId': 28},
#   {'success': True, 'objectId': 29},
#   {'success': True, 'objectId': 30},
#   {'success': True, 'objectId': 31},
#   {'success': True, 'objectId': 32},
#   {'success': True, 'objectId': 33},
#   {'success': True, 'objectId': 34},
#   {'success': True, 'objectId': 35},
#   {'success': True, 'objectId': 36},
#   {'success': True, 'objectId': 37},
#   {'success': True, 'objectId': 38},
#   {'success': True, 'objectId': 39},
#   {'success': True, 'objectId': 40},
#   {'success': True, 'objectId': 41},
#   {'success': True, 'objectId': 42},
#   {'success': True, 'objectId': 43},
#   {'success': True, 'objectId': 44},
#   {'success': True, 'objectId': 45},
#   {'success': True, 'objectId': 46},
#   {'success': True, 'objectId': 47},
#   {'success': True, 'objectId': 48},
#   {'success': True, 'objectId': 49},
#   {'success': True, 'objectId': 50},
#   {'success': True, 'objectId': 51},
#   {'success': True, 'objectId': 52},
#   {'success': True, 'objectId': 53},
#   {'success': True, 'objectId': 54},
#   {'success': True, 'objectId': 55},
#   {'success': True, 'objectId': 56},
#   {'success': True, 'objectId': 57},
#   {'success': True, 'objectId': 58},
#   {'success': True, 'objectId': 59},
#   {'success': True, 'objectId': 60},
#   {'success': True, 'objectId': 61},
#   {'success': True, 'objectId': 62},
#   {'success': True, 'objectId': 63},
#   {'success': True, 'objectId': 64},
#   {'success': True, 'objectId': 65},
#   {'success': True, 'objectId': 66},
#   {'success': True, 'objectId': 67},
#   {'success': True, 'objectId': 68}],
#  'updateResults': [],
#  'deleteResults': []}
